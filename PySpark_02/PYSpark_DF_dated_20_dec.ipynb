# %%
pip install faker
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: faker in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ae486c41-5d48-46c4-b2bf-0165687f6f30/lib/python3.9/site-packages (33.1.0)
# Requirement already satisfied: python-dateutil>=2.4 in /databricks/python3/lib/python3.9/site-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.9/site-packages (from faker) (4.1.1)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Python interpreter will be restarted.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()

from pyspark.sql.functions import col,lit,round,sum,avg,max,min,mean,count
import random
from faker import Faker
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
columns = StructType([
    StructField("StudentName", StringType(), True),
    StructField("Age", IntegerType(), True),
    StructField("Grade", StringType(), True),
    StructField("Gender", StringType(), True),
    StructField("Address", StringType(), True),
    StructField("City", StringType(), True),
    StructField("State", StringType(), True),
    StructField("Country", StringType(), True),
    StructField("Email", StringType(), True),
    StructField("Phone", StringType(), True)
])

fake = Faker()
# Generate 200 rows of random student data
data = [
    (
        fake.name(),
        random.randint(18, 25),
        random.choice(["A", "B", "C", "D", "E"]),
        random.choice(["Male", "Female"]),
        fake.address(),
        fake.city(),
        fake.state(),
        fake.country(),
        fake.email(),
        fake.phone_number()
    ) for _ in range(200)
]

# Create DataFrame
df = spark.createDataFrame(data, columns)

# %%
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# |    StudentName|Age|Grade|Gender|             Address|                City|       State|             Country|               Email|               Phone|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# | Jacob Shepherd| 25|    C|Female|723 Jennifer View...|            Lisabury|        Utah|          Costa Rica|   amy09@example.org|          3224548705|
# |   Laura Booker| 21|    C|Female|8411 Joshua Fork\...|            Johnport| Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|
# |   Monica Evans| 22|    E|Female|0492 Geoffrey Spr...|          Haileyland|    Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|          Mcgeemouth|        Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|
# |     Mark Welch| 25|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Assuming df is your DataFrame

# Specify the output path on DBFS (Databricks File System)
#output_path = "/dbfs/tmp/student_data_3.csv"  # Adjust this path to where you want to save the file in DBFS

# Write the DataFrame to a CSV file
#df.coalesce(1).write.option("header", "true").csv(output_path)

#print(f"CSV file has been saved to {output_path}")

# %%
df.printSchema()
# Out:
# root
#  |-- StudentName: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)

# %%
df.select("StudentName","Age").show(10)
# Out:
# +------------------+---+
# |       StudentName|Age|
# +------------------+---+
# |    Jacob Shepherd| 25|
# |      Laura Booker| 21|
# |      Monica Evans| 22|
# |   Caitlyn Andrews| 22|
# |        Mark Welch| 25|
# |    Kristy Freeman| 19|
# |Christopher Guerra| 18|
# |    Jason Jacobson| 20|
# |      Brian Miller| 23|
# |       Shawn Young| 22|
# +------------------+---+
# only showing top 10 rows

# %%
df.select("*").show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# |    StudentName|Age|Grade|Gender|             Address|                City|       State|             Country|               Email|               Phone|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# | Jacob Shepherd| 25|    C|Female|723 Jennifer View...|            Lisabury|        Utah|          Costa Rica|   amy09@example.org|          3224548705|
# |   Laura Booker| 21|    C|Female|8411 Joshua Fork\...|            Johnport| Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|
# |   Monica Evans| 22|    E|Female|0492 Geoffrey Spr...|          Haileyland|    Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|          Mcgeemouth|        Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|
# |     Mark Welch| 25|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.select(df.columns[0:4]).show()
# Out:
# +------------------+---+-----+------+
# |       StudentName|Age|Grade|Gender|
# +------------------+---+-----+------+
# |    Jacob Shepherd| 25|    C|Female|
# |      Laura Booker| 21|    C|Female|
# |      Monica Evans| 22|    E|Female|
# |   Caitlyn Andrews| 22|    A|  Male|
# |        Mark Welch| 25|    E|Female|
# |    Kristy Freeman| 19|    A|  Male|
# |Christopher Guerra| 18|    E|Female|
# |    Jason Jacobson| 20|    A|  Male|
# |      Brian Miller| 23|    B|  Male|
# |       Shawn Young| 22|    A|  Male|
# |  Jonathan Sanchez| 23|    E|  Male|
# |      Joshua Rivas| 25|    C|Female|
# |   Jessica Cochran| 21|    B|  Male|
# |       Alison Hill| 23|    E|  Male|
# |     Sheila Wright| 19|    E|  Male|
# |        Mike Roman| 22|    A|Female|
# |   Kimberly Brewer| 18|    C|  Male|
# |  Joseph Gutierrez| 24|    A|Female|
# |    James Gonzalez| 23|    A|Female|
# |       Alison Vega| 25|    B|Female|
# +------------------+---+-----+------+
# only showing top 20 rows

# %%
df2=df.withColumn("Age",col("Age").cast("String"))

# %%
df2.printSchema()
# Out:
# root
#  |-- StudentName: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)

# %%
df2 = df2.withColumn("Age",col("Age").cast("integer"))

# %%
# Adding value to exsiting column value by 10
df2=df2.withColumn("Age",col("Age")+10)

# %%
df2.show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# |    StudentName|Age|Grade|Gender|             Address|                City|       State|             Country|               Email|               Phone|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# | Jacob Shepherd| 35|    C|Female|723 Jennifer View...|            Lisabury|        Utah|          Costa Rica|   amy09@example.org|          3224548705|
# |   Laura Booker| 31|    C|Female|8411 Joshua Fork\...|            Johnport| Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|
# |   Monica Evans| 32|    E|Female|0492 Geoffrey Spr...|          Haileyland|    Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|
# |Caitlyn Andrews| 32|    A|  Male|27625 Sanchez Sta...|          Mcgeemouth|        Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|
# |     Mark Welch| 35|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df=df.withColumn("Marks",col("Age")+15)
df.select("StudentName","Marks").show(5)
# Out:
# +---------------+-----+
# |    StudentName|Marks|
# +---------------+-----+
# | Jacob Shepherd|   40|
# |   Laura Booker|   36|
# |   Monica Evans|   37|
# |Caitlyn Andrews|   37|
# |     Mark Welch|   40|
# +---------------+-----+
# only showing top 5 rows

# %%
df= df.withColumn("Mob_no",lit(840980422))
df.select('StudentName',"Mob_no").show(5)
# Out:
# +---------------+---------+
# |    StudentName|   Mob_no|
# +---------------+---------+
# | Jacob Shepherd|840980422|
# |   Laura Booker|840980422|
# |   Monica Evans|840980422|
# |Caitlyn Andrews|840980422|
# |     Mark Welch|840980422|
# +---------------+---------+
# only showing top 5 rows

# %%
df = df.withColumn("Marks", col("Marks") + 10).withColumn("Author", lit("tanya"))
df.select("StudentName", "Marks", "Author").show(5)
# Out:
# +---------------+-----+------+
# |    StudentName|Marks|Author|
# +---------------+-----+------+
# | Jacob Shepherd|   50| tanya|
# |   Laura Booker|   46| tanya|
# |   Monica Evans|   47| tanya|
# |Caitlyn Andrews|   47| tanya|
# |     Mark Welch|   50| tanya|
# +---------------+-----+------+
# only showing top 5 rows

# %%
df=df.withColumnRenamed("StudentName","Student_name")
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+------+
# |   Student_name|Age|Grade|Gender|             Address|                City|       State|             Country|               Email|               Phone|Marks|   Mob_no|Author|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+------+
# | Jacob Shepherd| 25|    C|Female|723 Jennifer View...|            Lisabury|        Utah|          Costa Rica|   amy09@example.org|          3224548705|   50|840980422| tanya|
# |   Laura Booker| 21|    C|Female|8411 Joshua Fork\...|            Johnport| Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|   46|840980422| tanya|
# |   Monica Evans| 22|    E|Female|0492 Geoffrey Spr...|          Haileyland|    Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|   47|840980422| tanya|
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|          Mcgeemouth|        Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|   47|840980422| tanya|
# |     Mark Welch| 25|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|   50|840980422| tanya|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+------+
# only showing top 5 rows

# %%
df = df.withColumnRenamed("Author","Author_of_data").withColumnRenamed("Address","Full_address")
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |   Student_name|Age|Grade|Gender|        Full_address|                City|       State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# | Jacob Shepherd| 25|    C|Female|723 Jennifer View...|            Lisabury|        Utah|          Costa Rica|   amy09@example.org|          3224548705|   50|840980422|         tanya|
# |   Laura Booker| 21|    C|Female|8411 Joshua Fork\...|            Johnport| Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|   46|840980422|         tanya|
# |   Monica Evans| 22|    E|Female|0492 Geoffrey Spr...|          Haileyland|    Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|   47|840980422|         tanya|
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|          Mcgeemouth|        Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|   47|840980422|         tanya|
# |     Mark Welch| 25|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|   50|840980422|         tanya|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 5 rows

# %%
df.select(col("Age").alias("Student_age")).show(5)
# Out:
# +-----------+
# |Student_age|
# +-----------+
# |         25|
# |         21|
# |         22|
# |         22|
# |         25|
# +-----------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Student_name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Full_address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- Marks: integer (nullable = true)
#  |-- Mob_no: integer (nullable = false)
#  |-- Author_of_data: string (nullable = false)

# %%
df.filter(df.Gender == "Female").show()
# Out:
# +--------------------+---+-----+------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |        Student_name|Age|Grade|Gender|        Full_address|                City|         State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +--------------------+---+-----+------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |      Jacob Shepherd| 25|    C|Female|723 Jennifer View...|            Lisabury|          Utah|          Costa Rica|   amy09@example.org|          3224548705|   50|840980422|         tanya|
# |        Laura Booker| 21|    C|Female|8411 Joshua Fork\...|            Johnport|   Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|   46|840980422|         tanya|
# |        Monica Evans| 22|    E|Female|0492 Geoffrey Spr...|          Haileyland|      Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|   47|840980422|         tanya|
# |          Mark Welch| 25|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|  North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|   50|840980422|         tanya|
# |  Christopher Guerra| 18|    E|Female|12942 Bradley Pik...|           Bushville|       Wyoming|               Palau|garciacathy@examp...|001-848-671-5839x...|   43|840980422|         tanya|
# |        Joshua Rivas| 25|    C|Female|6897 Mary Spurs S...|          Juliemouth|      Missouri|              Guinea|  luis26@example.org|  (413)976-7651x1961|   50|840980422|         tanya|
# |          Mike Roman| 22|    A|Female|423 Simpson Ways ...|       New Catherine|North Carolina|British Indian Oc...|natalievillegas@e...| +1-302-698-8443x229|   47|840980422|         tanya|
# |    Joseph Gutierrez| 24|    A|Female|32330 Smith Spur ...|           Cruzshire|        Hawaii|              Mexico|cmckinney@example...|001-873-422-9380x...|   49|840980422|         tanya|
# |      James Gonzalez| 23|    A|Female|18383 Travis Cres...|        North Marcus|       Florida|            Portugal|davidcrosby@examp...|        384-763-8821|   48|840980422|         tanya|
# |         Alison Vega| 25|    B|Female|0379 Barton Villa...|     West Justinport|       Montana|United States Min...|meaganperez@examp...|    834-439-8112x440|   50|840980422|         tanya|
# |     Gregory Cox DDS| 18|    A|Female|598 Hunt Squares ...|      Lake Davidfort| Massachusetts|        Saint Martin|  mortiz@example.net|  384.507.1812x79220|   43|840980422|         tanya|
# |      Joshua Cameron| 18|    C|Female|83223 Robert Loop...|        South Robert|        Hawaii|                Fiji|  pberry@example.net|   535.613.1382x5043|   43|840980422|         tanya|
# |    Christine Foster| 21|    A|Female|87826 Thomas Forg...|     West Stacymouth|       Alabama|        Saint Martin|dgonzales@example...|  773.723.7185x88289|   46|840980422|         tanya|
# |Christopher Jennings| 20|    C|Female|587 Travis Burg A...|      Lake Bradmouth|  Rhode Island|              Israel|    tlee@example.net|001-896-202-6118x562|   45|840980422|         tanya|
# |      Michael Campos| 18|    E|Female|1576 Simmons Rapi...|          Harrisport|         Texas|             Somalia|edwardssteven@exa...|   477-687-7976x7994|   43|840980422|         tanya|
# |         Kelly Clark| 24|    C|Female|269 Strong Throug...|         Angelaburgh|        Alaska|       New Caledonia|chavezdaniel@exam...| +1-211-871-6463x107|   49|840980422|         tanya|
# |     Cindy Macdonald| 22|    C|Female|47357 Ryan Haven\...|    West Michaelstad|         Idaho|             Uruguay|perezteresa@examp...|  (873)809-0252x3366|   47|840980422|         tanya|
# |      Deanna Daniels| 25|    B|Female|309 David Brook\n...|   South Tiffanytown|      New York|              Israel|cookcharles@examp...|          4747982317|   50|840980422|         tanya|
# |   Caroline Martinez| 25|    D|Female|045 Daniel Plains...|          Georgeside|       Alabama|              Guyana| imartin@example.org|001-716-901-5204x388|   50|840980422|         tanya|
# |        John Cox DDS| 24|    A|Female|4327 Taylor Drive...|           Larryfurt|        Kansas|              Norway|katrina70@example...|        440-839-1682|   49|840980422|         tanya|
# +--------------------+---+-----+------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 20 rows

# %%
df.select("Student_name","Gender","Age").filter(df.Gender == "Female").show(5)
# Out:
# +------------------+------+---+
# |      Student_name|Gender|Age|
# +------------------+------+---+
# |    Jacob Shepherd|Female| 25|
# |      Laura Booker|Female| 21|
# |      Monica Evans|Female| 22|
# |        Mark Welch|Female| 25|
# |Christopher Guerra|Female| 18|
# +------------------+------+---+
# only showing top 5 rows

# %%
df.filter(col("Gender") == "Male").show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |   Student_name|Age|Grade|Gender|        Full_address|          City|        State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +---------------+---+-----+------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|    Mcgeemouth|         Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|   47|840980422|         tanya|
# | Kristy Freeman| 19|    A|  Male|2389 White Ramp\n...|  Lake Anthony|   New Jersey|Saint Vincent and...|scottlauren@examp...|    791.233.5369x259|   44|840980422|         tanya|
# | Jason Jacobson| 20|    A|  Male|175 Devon Cliffs\...|   Jefferystad|     Illinois|    Marshall Islands|combsmonique@exam...|        478-326-0509|   45|840980422|         tanya|
# |   Brian Miller| 23|    B|  Male|USNV Fisher\nFPO ...|    New Angela|    Louisiana|              Guyana|oroberts@example.com|   (507)564-0732x824|   48|840980422|         tanya|
# |    Shawn Young| 22|    A|  Male|6798 Ryan Traffic...|Wilkinsonburgh|Massachusetts|          Mauritania|colesandra@exampl...|     +1-510-768-3260|   47|840980422|         tanya|
# +---------------+---+-----+------+--------------------+--------------+-------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 5 rows

# %%
df.select("Student_name","Gender","Age").filter(col("Gender")=="Male").show()
# Out:
# +----------------+------+---+
# |    Student_name|Gender|Age|
# +----------------+------+---+
# | Caitlyn Andrews|  Male| 22|
# |  Kristy Freeman|  Male| 19|
# |  Jason Jacobson|  Male| 20|
# |    Brian Miller|  Male| 23|
# |     Shawn Young|  Male| 22|
# |Jonathan Sanchez|  Male| 23|
# | Jessica Cochran|  Male| 21|
# |     Alison Hill|  Male| 23|
# |   Sheila Wright|  Male| 19|
# | Kimberly Brewer|  Male| 18|
# | Stephanie Brown|  Male| 19|
# |   Mallory Green|  Male| 21|
# |    Brett Arnold|  Male| 24|
# |    James Foster|  Male| 23|
# | Michael Johnson|  Male| 21|
# |  Craig Mitchell|  Male| 19|
# |     Alan Graves|  Male| 23|
# |       Linda Fox|  Male| 24|
# |     Daniel Shaw|  Male| 20|
# |Brian Mclaughlin|  Male| 21|
# +----------------+------+---+
# only showing top 20 rows

# %%
df.filter((df.Gender == "Male") & (df.Age == 24)).show(5)
# Out:
# +-------------+---+-----+------+--------------------+-----------+------------+---------------+--------------------+--------------------+-----+---------+--------------+
# | Student_name|Age|Grade|Gender|        Full_address|       City|       State|        Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +-------------+---+-----+------+--------------------+-----------+------------+---------------+--------------------+--------------------+-----+---------+--------------+
# | Brett Arnold| 24|    B|  Male|8296 Todd Ways\nS...|Johnsonbury|    Arkansas|      Indonesia|uphillips@example...|   272-348-3052x7804|   49|840980422|         tanya|
# |    Linda Fox| 24|    A|  Male|26416 Joshua Stre...|Kennethstad|    Delaware|     Azerbaijan|   fshaw@example.net|        207.891.5528|   49|840980422|         tanya|
# | John Vincent| 24|    D|  Male|PSC 1399, Box 174...|  West Mary|Pennsylvania|North Macedonia|ematthews@example...|   335.357.5042x2258|   49|840980422|         tanya|
# |   Joel Mcgee| 24|    C|  Male|5129 Michael Pine...|   Cruzbury|     Indiana|    Philippines|jeffrey41@example...|001-649-754-7458x377|   49|840980422|         tanya|
# |Mark Sullivan| 24|    E|  Male|2392 Taylor Fall ...| Stokesberg|    New York|   Saint Martin|anthony00@example...|       (440)799-3932|   49|840980422|         tanya|
# +-------------+---+-----+------+--------------------+-----------+------------+---------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 5 rows

# %%
## Filtering using &(and) conditions
 
df.select("Student_name","Gender","Age").filter((df.Gender == "Male") & (df.Age == 24)).show(5)
# Out:
# +-------------+------+---+
# | Student_name|Gender|Age|
# +-------------+------+---+
# | Brett Arnold|  Male| 24|
# |    Linda Fox|  Male| 24|
# | John Vincent|  Male| 24|
# |   Joel Mcgee|  Male| 24|
# |Mark Sullivan|  Male| 24|
# +-------------+------+---+
# only showing top 5 rows

# %%
## Filtering using | (or) conditions
df.select("Student_name","Gender","Age").filter((df.Gender == "Male") | (df.Age == 24)).show(5)
# Out:
# +---------------+------+---+
# |   Student_name|Gender|Age|
# +---------------+------+---+
# |Caitlyn Andrews|  Male| 22|
# | Kristy Freeman|  Male| 19|
# | Jason Jacobson|  Male| 20|
# |   Brian Miller|  Male| 23|
# |    Shawn Young|  Male| 22|
# +---------------+------+---+
# only showing top 5 rows

# %%
distinct_country = df.select("Country").distinct()
distinct_country.show()
# Out:
# +--------------------+
# |             Country|
# +--------------------+
# |              Guyana|
# |            Cambodia|
# |               Palau|
# |British Indian Oc...|
# |    Marshall Islands|
# |          Mauritania|
# |               Congo|
# |              Mexico|
# |               Aruba|
# |Saint Vincent and...|
# |            Honduras|
# |       French Guiana|
# |    Pitcairn Islands|
# |        Saint Martin|
# |              Guinea|
# |          Seychelles|
# | Antigua and Barbuda|
# |United States Min...|
# |            Portugal|
# |          Costa Rica|
# +--------------------+
# only showing top 20 rows

# %%
# Filtering using isin function

df.select("Student_name","Gender","Age","Country").filter(df.Country.isin(["Kazakhstan","Spain"])).show(5)
# Out:
# +------------+------+---+-------+
# |Student_name|Gender|Age|Country|
# +------------+------+---+-------+
# +------------+------+---+-------+

# %%
# filter all data whoes country starts with "K"

df.select("Student_name","Gender","Age","Country").filter(df.Country.startswith("K")).show(5)
# Out:
# +----------------+------+---+--------+
# |    Student_name|Gender|Age| Country|
# +----------------+------+---+--------+
# |      Cindy Rios|Female| 24|   Korea|
# |    Joyce Howard|Female| 25|  Kuwait|
# |Crystal Sullivan|  Male| 18|Kiribati|
# +----------------+------+---+--------+

# %%
# filter all data whoes country end with "K"

df.select("Student_name","Gender","Age","Country").filter(df.Country.endswith("n")).show(5)
# Out:
# +----------------+------+---+------------+
# |    Student_name|Gender|Age|     Country|
# +----------------+------+---+------------+
# | Gregory Cox DDS|Female| 18|Saint Martin|
# |Christine Foster|Female| 21|Saint Martin|
# |       Linda Fox|  Male| 24|  Azerbaijan|
# |Brian Mclaughlin|  Male| 21| Isle of Man|
# |  Kelly Jennings|  Male| 23|       Gabon|
# +----------------+------+---+------------+
# only showing top 5 rows

# %%
# filter all data whoes country contains with "An"

df.select("Student_name","Gender","Age","Country").filter(df.Country.contains("An")).show(5)
# Out:
# +-----------------+------+---+--------------------+
# |     Student_name|Gender|Age|             Country|
# +-----------------+------+---+--------------------+
# |  Kimberly Brewer|  Male| 18| Antigua and Barbuda|
# |   Paul Hernandez|Female| 22|Netherlands Antilles|
# |Michael Macdonald|  Male| 23|Antarctica (the t...|
# |     Jack Rosales|Female| 25|              Angola|
# |       Drew White|Female| 21|            Anguilla|
# +-----------------+------+---+--------------------+
# only showing top 5 rows

# %%
# filter all data whoes country starts with "An" using(Like)

df.select("Student_name","Gender","Age","Country").filter(df.Country.like("An%")).show(5)
# Out:
# +--------------------+------+---+--------------------+
# |        Student_name|Gender|Age|             Country|
# +--------------------+------+---+--------------------+
# |     Kimberly Brewer|  Male| 18| Antigua and Barbuda|
# |   Michael Macdonald|  Male| 23|Antarctica (the t...|
# |        Jack Rosales|Female| 25|              Angola|
# |          Drew White|Female| 21|            Anguilla|
# |Mrs. Sabrina Orti...|Female| 22|              Angola|
# +--------------------+------+---+--------------------+

# %%
df.printSchema()
# Out:
# root
#  |-- Student_name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Full_address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- Marks: integer (nullable = true)
#  |-- Mob_no: integer (nullable = false)
#  |-- Author_of_data: string (nullable = false)

# %%
df.select("Student_name","Marks").show(5)
# Out:
# +---------------+-----+
# |   Student_name|Marks|
# +---------------+-----+
# | Jacob Shepherd|   50|
# |   Laura Booker|   46|
# |   Monica Evans|   47|
# |Caitlyn Andrews|   47|
# |     Mark Welch|   50|
# +---------------+-----+
# only showing top 5 rows

# %%
df = df.withColumn("Percentage",col("Marks")+20).withColumn("Total_marks",lit(120))
df.select("Student_name","Marks","Percentage","Total_marks").show(5)
# Out:
# +---------------+-----+----------+-----------+
# |   Student_name|Marks|Percentage|Total_marks|
# +---------------+-----+----------+-----------+
# | Jacob Shepherd|   50|        70|        120|
# |   Laura Booker|   46|        66|        120|
# |   Monica Evans|   47|        67|        120|
# |Caitlyn Andrews|   47|        67|        120|
# |     Mark Welch|   50|        70|        120|
# +---------------+-----+----------+-----------+
# only showing top 5 rows

# %%
df=df.withColumn("Avg_marks",col("Marks")/col("Total_marks")*100)

df.select("Student_name","Marks","Percentage","Total_marks","Avg_marks").show(5)
# Out:
# +---------------+-----+----------+-----------+------------------+
# |   Student_name|Marks|Percentage|Total_marks|         Avg_marks|
# +---------------+-----+----------+-----------+------------------+
# | Jacob Shepherd|   50|        70|        120| 41.66666666666667|
# |   Laura Booker|   46|        66|        120|38.333333333333336|
# |   Monica Evans|   47|        67|        120|39.166666666666664|
# |Caitlyn Andrews|   47|        67|        120|39.166666666666664|
# |     Mark Welch|   50|        70|        120| 41.66666666666667|
# +---------------+-----+----------+-----------+------------------+
# only showing top 5 rows

# %%
df_check = df.select("Student_name","Percentage").filter(df.Percentage >= 50)

df_check.show()
# Out:
# +------------------+----------+
# |      Student_name|Percentage|
# +------------------+----------+
# |    Jacob Shepherd|        70|
# |      Laura Booker|        66|
# |      Monica Evans|        67|
# |   Caitlyn Andrews|        67|
# |        Mark Welch|        70|
# |    Kristy Freeman|        64|
# |Christopher Guerra|        63|
# |    Jason Jacobson|        65|
# |      Brian Miller|        68|
# |       Shawn Young|        67|
# |  Jonathan Sanchez|        68|
# |      Joshua Rivas|        70|
# |   Jessica Cochran|        66|
# |       Alison Hill|        68|
# |     Sheila Wright|        64|
# |        Mike Roman|        67|
# |   Kimberly Brewer|        63|
# |  Joseph Gutierrez|        69|
# |    James Gonzalez|        68|
# |       Alison Vega|        70|
# +------------------+----------+
# only showing top 20 rows

# %%
df.select("Student_name","marks","Percentage").filter(df.Percentage < 70).show()
# Out:
# +--------------------+-----+----------+
# |        Student_name|marks|Percentage|
# +--------------------+-----+----------+
# |        Laura Booker|   46|        66|
# |        Monica Evans|   47|        67|
# |     Caitlyn Andrews|   47|        67|
# |      Kristy Freeman|   44|        64|
# |  Christopher Guerra|   43|        63|
# |      Jason Jacobson|   45|        65|
# |        Brian Miller|   48|        68|
# |         Shawn Young|   47|        67|
# |    Jonathan Sanchez|   48|        68|
# |     Jessica Cochran|   46|        66|
# |         Alison Hill|   48|        68|
# |       Sheila Wright|   44|        64|
# |          Mike Roman|   47|        67|
# |     Kimberly Brewer|   43|        63|
# |    Joseph Gutierrez|   49|        69|
# |      James Gonzalez|   48|        68|
# |     Gregory Cox DDS|   43|        63|
# |      Joshua Cameron|   43|        63|
# |    Christine Foster|   46|        66|
# |Christopher Jennings|   45|        65|
# +--------------------+-----+----------+
# only showing top 20 rows

# %%
# count all data from in dataframe
df.count()
# Out:
# Out[40]: 200

# %%
df.select("Country").distinct().show()
# Out:
# +--------------------+
# |             Country|
# +--------------------+
# |              Guyana|
# |            Cambodia|
# |               Palau|
# |British Indian Oc...|
# |    Marshall Islands|
# |          Mauritania|
# |               Congo|
# |              Mexico|
# |               Aruba|
# |Saint Vincent and...|
# |            Honduras|
# |       French Guiana|
# |    Pitcairn Islands|
# |        Saint Martin|
# |              Guinea|
# |          Seychelles|
# | Antigua and Barbuda|
# |United States Min...|
# |            Portugal|
# |          Costa Rica|
# +--------------------+
# only showing top 20 rows

# %%
df.filter(df.Country == "Eritrea").count()
# Out:
# Out[42]: 1

# %%
df.distinct().count()
# Out:
# Out[43]: 200

# %%
df.select("Student_name").distinct().show()
# Out:
# +----------------+
# |    Student_name|
# +----------------+
# |     Alison Hill|
# |     Shawn Young|
# |Joseph Gutierrez|
# |  James Gonzalez|
# |  Jacob Shepherd|
# | Jessica Cochran|
# |  Jason Jacobson|
# |     Alison Vega|
# |      Mike Roman|
# |   Sheila Wright|
# |    Laura Booker|
# |      Mark Welch|
# |    Joshua Rivas|
# | Gregory Cox DDS|
# |    Brian Miller|
# |Jonathan Sanchez|
# |    Monica Evans|
# | Caitlyn Andrews|
# |  Kristy Freeman|
# | Kimberly Brewer|
# +----------------+
# only showing top 20 rows

# %%
#df=df.dropDuplicates(["Country"]).show()

# %%
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# |   Student_name|Age|Grade|Gender|        Full_address|                City|       State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|Percentage|Total_marks|         Avg_marks|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# | Jacob Shepherd| 25|    C|Female|723 Jennifer View...|            Lisabury|        Utah|          Costa Rica|   amy09@example.org|          3224548705|   50|840980422|         tanya|        70|        120| 41.66666666666667|
# |   Laura Booker| 21|    C|Female|8411 Joshua Fork\...|            Johnport| Connecticut|            Cambodia|fernandezemily@ex...|        679-881-6275|   46|840980422|         tanya|        66|        120|38.333333333333336|
# |   Monica Evans| 22|    E|Female|0492 Geoffrey Spr...|          Haileyland|    Arkansas|            Honduras|jlivingston@examp...|        914-880-9150|   47|840980422|         tanya|        67|        120|39.166666666666664|
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|          Mcgeemouth|        Iowa|    Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|   47|840980422|         tanya|        67|        120|39.166666666666664|
# |     Mark Welch| 25|    E|Female|0737 Lowe Lakes\n...|West Christopherm...|North Dakota|Syrian Arab Republic|michael92@example...|        674-385-8130|   50|840980422|         tanya|        70|        120| 41.66666666666667|
# +---------------+---+-----+------+--------------------+--------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# only showing top 5 rows

# %%
df_unique_gender = df.dropDuplicates(['Gender'])
df_unique_gender.distinct().count()
df_unique_gender.distinct().show()
# Out:
# +---------------+---+-----+------+--------------------+----------+-----+----------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# |   Student_name|Age|Grade|Gender|        Full_address|      City|State|         Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|Percentage|Total_marks|         Avg_marks|
# +---------------+---+-----+------+--------------------+----------+-----+----------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# | Jacob Shepherd| 25|    C|Female|723 Jennifer View...|  Lisabury| Utah|      Costa Rica|   amy09@example.org|          3224548705|   50|840980422|         tanya|        70|        120| 41.66666666666667|
# |Caitlyn Andrews| 22|    A|  Male|27625 Sanchez Sta...|Mcgeemouth| Iowa|Pitcairn Islands|trevorpotts@examp...|001-580-808-8201x...|   47|840980422|         tanya|        67|        120|39.166666666666664|
# +---------------+---+-----+------+--------------------+----------+-----+----------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+

# %%
# sorting ascending order
df.select('Student_name',"Marks").sort("Marks").show(5)
# Out:
# +----------------+-----+
# |    Student_name|Marks|
# +----------------+-----+
# |  Michael Campos|   43|
# |Crystal Sullivan|   43|
# |  Sally Franklin|   43|
# |  Sandra Wheeler|   43|
# |     Cody Thomas|   43|
# +----------------+-----+
# only showing top 5 rows

# %%
# sorting ascending order
df.select('Student_name',"Marks").orderBy("Marks").show(5)
# Out:
# +-----------------+-----+
# |     Student_name|Marks|
# +-----------------+-----+
# |      Cody Thomas|   43|
# |Charles Armstrong|   43|
# |   Michael Campos|   43|
# |   Austin Johnson|   43|
# | Crystal Sullivan|   43|
# +-----------------+-----+
# only showing top 5 rows

# %%
# sorting descending order
df.select('Student_name',"Marks").sort(df.Marks.desc()).show(5)
# Out:
# +-----------------+-----+
# |     Student_name|Marks|
# +-----------------+-----+
# |Margaret Martinez|   50|
# |   Jennifer Greer|   50|
# |     Joshua Rivas|   50|
# |   Jordan Roberts|   50|
# |      Dakota Tran|   50|
# +-----------------+-----+
# only showing top 5 rows

# %%
# sorting descending order
df.select('Student_name',"Marks").orderBy(df.Marks.desc()).show(5)
# Out:
# +-----------------+-----+
# |     Student_name|Marks|
# +-----------------+-----+
# |   Deanna Daniels|   50|
# |      Dakota Tran|   50|
# |   Jennifer Greer|   50|
# | Margaret Delgado|   50|
# |Margaret Martinez|   50|
# +-----------------+-----+
# only showing top 5 rows

# %%
# Gender wise sum of marks
df.groupBy("Gender").sum("Marks").show()

# Gender wise count 
df.groupBy("Gender").count().show()

# Gender wise max of marks
df.groupBy("Gender").max("Marks").show()

# Gender wise min of marks
df.groupBy("Gender").min("Marks").show()

# Gender wise avg of marks
df.groupBy("Gender").avg("Marks").show()
# Out:
# +------+----------+
# |Gender|sum(Marks)|
# +------+----------+
# |Female|      4838|
# |  Male|      4494|
# +------+----------+
#
# +------+-----+
# |Gender|count|
# +------+-----+
# |Female|  103|
# |  Male|   97|
# +------+-----+
#
# +------+----------+
# |Gender|max(Marks)|
# +------+----------+
# |Female|        50|
# |  Male|        50|
# +------+----------+
#
# +------+----------+
# |Gender|min(Marks)|
# +------+----------+
# |Female|        43|
# |  Male|        43|
# +------+----------+
#
# +------+------------------+
# |Gender|        avg(Marks)|
# +------+------------------+
# |Female|46.970873786407765|
# |  Male|46.329896907216494|
# +------+------------------+

# %%
# Gender wise count
df.groupBy("Gender").count().show()

# Gender,Country wise count
df.groupBy("Country","Gender").count().show()
# Out:
# +------+-----+
# |Gender|count|
# +------+-----+
# |Female|  103|
# |  Male|   97|
# +------+-----+
#
# +--------------------+------+-----+
# |             Country|Gender|count|
# +--------------------+------+-----+
# |            Honduras|Female|    1|
# |Syrian Arab Republic|Female|    1|
# |              Guyana|  Male|    1|
# |          Mauritania|  Male|    1|
# |            Cambodia|Female|    1|
# |    Marshall Islands|  Male|    1|
# |               Congo|  Male|    3|
# |United States Min...|Female|    1|
# |               Palau|Female|    1|
# |          Costa Rica|Female|    1|
# |       French Guiana|  Male|    1|
# |          Seychelles|  Male|    1|
# |              Israel|Female|    2|
# |            Portugal|Female|    1|
# |               Aruba|  Male|    2|
# |        Saint Martin|Female|    3|
# |British Indian Oc...|Female|    1|
# |   Equatorial Guinea|  Male|    1|
# |Saint Vincent and...|  Male|    1|
# |    Pitcairn Islands|  Male|    1|
# +--------------------+------+-----+
# only showing top 20 rows

# %%
df.groupBy("Gender").agg(count("*").alias("Total_count"),sum("Marks").alias("Sum_of_marks"),avg("Marks").alias("Avg_of_marks"),min("Marks").alias("Min_of_marks"),max("Marks").alias("max_of_marks")).show()
# Out:
# +------+-----------+------------+------------------+------------+------------+
# |Gender|Total_count|Sum_of_marks|      Avg_of_marks|Min_of_marks|max_of_marks|
# +------+-----------+------------+------------------+------------+------------+
# |Female|        103|        4838|46.970873786407765|          43|          50|
# |  Male|         97|        4494|46.329896907216494|          43|          50|
# +------+-----------+------------+------------------+------------+------------+

# %%
df.groupBy("Country","Gender").agg(count("*").alias("Total_count"),sum("Marks").alias("Sum_of_marks"),avg("Marks").alias("Avg_of_marks"),min("Marks").alias("Min_of_marks"),max("Marks").alias("max_of_marks")).show()
# Out:
# +--------------------+------+-----------+------------+------------------+------------+------------+
# |             Country|Gender|Total_count|Sum_of_marks|      Avg_of_marks|Min_of_marks|max_of_marks|
# +--------------------+------+-----------+------------+------------------+------------+------------+
# |            Honduras|Female|          1|          47|              47.0|          47|          47|
# |Syrian Arab Republic|Female|          1|          50|              50.0|          50|          50|
# |              Guyana|  Male|          1|          48|              48.0|          48|          48|
# |          Mauritania|  Male|          1|          47|              47.0|          47|          47|
# |            Cambodia|Female|          1|          46|              46.0|          46|          46|
# |    Marshall Islands|  Male|          1|          45|              45.0|          45|          45|
# |               Congo|  Male|          3|         134|44.666666666666664|          44|          45|
# |United States Min...|Female|          1|          50|              50.0|          50|          50|
# |               Palau|Female|          1|          43|              43.0|          43|          43|
# |          Costa Rica|Female|          1|          50|              50.0|          50|          50|
# |       French Guiana|  Male|          1|          46|              46.0|          46|          46|
# |          Seychelles|  Male|          1|          48|              48.0|          48|          48|
# |              Israel|Female|          2|          95|              47.5|          45|          50|
# |            Portugal|Female|          1|          48|              48.0|          48|          48|
# |               Aruba|  Male|          2|          92|              46.0|          44|          48|
# |        Saint Martin|Female|          3|         134|44.666666666666664|          43|          46|
# |British Indian Oc...|Female|          1|          47|              47.0|          47|          47|
# |   Equatorial Guinea|  Male|          1|          44|              44.0|          44|          44|
# |Saint Vincent and...|  Male|          1|          44|              44.0|          44|          44|
# |    Pitcairn Islands|  Male|          1|          47|              47.0|          47|          47|
# +--------------------+------+-----------+------------+------------------+------------+------------+
# only showing top 20 rows

# %%
d1=df.groupBy("Country").agg(count('*').alias('Total'))
d1.select("Country",'Total').sort(d1.Total.desc()).filter(d1.Total > 1).show()
# Out:
# +--------------------+-----+
# |             Country|Total|
# +--------------------+-----+
# |               Congo|    4|
# |        Saint Martin|    4|
# |              Mexico|    3|
# |United States Min...|    3|
# |           Guatemala|    3|
# |        Burkina Faso|    3|
# |         Philippines|    3|
# |              Greece|    3|
# |Slovakia (Slovak ...|    3|
# |              Monaco|    3|
# |United States of ...|    3|
# |United States Vir...|    3|
# |             Uruguay|    2|
# |           Indonesia|    2|
# |French Southern T...|    2|
# |Lao People's Demo...|    2|
# |               Aruba|    2|
# |          Micronesia|    2|
# |Heard Island and ...|    2|
# |              Cyprus|    2|
# +--------------------+-----+
# only showing top 20 rows
