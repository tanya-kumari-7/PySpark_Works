# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col,lit,min,max,avg,mean,sum,count,when,udf,rank,dense_rank,row_number
from pyspark.sql.window import Window

spark = SparkSession.builder.appName('DF_working_2').getOrCreate()
