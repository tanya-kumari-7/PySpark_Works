# %%
pip install faker
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: faker in /local_disk0/.ephemeral_nfs/envs/pythonEnv-a755f0df-e2fc-436d-9a44-30699173931b/lib/python3.9/site-packages (33.1.0)
# Requirement already satisfied: python-dateutil>=2.4 in /databricks/python3/lib/python3.9/site-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.9/site-packages (from faker) (4.1.1)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Python interpreter will be restarted.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()

from pyspark.sql.functions import col,lit,round,sum,avg,max,min,mean,count
import random
from faker import Faker
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
columns = StructType([
    StructField("StudentName", StringType(), True),
    StructField("Age", IntegerType(), True),
    StructField("Grade", StringType(), True),
    StructField("Gender", StringType(), True),
    StructField("Address", StringType(), True),
    StructField("City", StringType(), True),
    StructField("State", StringType(), True),
    StructField("Country", StringType(), True),
    StructField("Email", StringType(), True),
    StructField("Phone", StringType(), True)
])

fake = Faker()
# Generate 200 rows of random student data
data = [
    (
        fake.name(),
        random.randint(18, 25),
        random.choice(["A", "B", "C", "D", "E"]),
        random.choice(["Male", "Female"]),
        fake.address(),
        fake.city(),
        fake.state(),
        fake.country(),
        fake.email(),
        fake.phone_number()
    ) for _ in range(200)
]

# Create DataFrame
df = spark.createDataFrame(data, columns)

# %%
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# |    StudentName|Age|Grade|Gender|             Address|               City|       State|      Country|               Email|               Phone|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# |    Dean Wilson| 19|    E|  Male|217 Charles Trail...|        Lake Andrew|     Georgia|Liechtenstein|marilyn71@example...|    489-336-6475x408|
# | Kirsten Garner| 23|    C|  Male|239 Herrera Knoll...|   South Janethaven|      Alaska|    Indonesia| imercer@example.org|001-537-249-3192x174|
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|        Haiti|christinereynolds...|        948-417-3494|
# | Jacob Mitchell| 19|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|  Philippines| laura50@example.com|001-854-656-0336x...|
# | Elizabeth Lowe| 19|    D|  Male|0582 Daugherty Dr...|           Lunaview|   Wisconsin|     Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Assuming df is your DataFrame

# Specify the output path on DBFS (Databricks File System)
#output_path = "/dbfs/tmp/student_data_3.csv"  # Adjust this path to where you want to save the file in DBFS

# Write the DataFrame to a CSV file
#df.coalesce(1).write.option("header", "true").csv(output_path)

#print(f"CSV file has been saved to {output_path}")

# %%
df.printSchema()
# Out:
# root
#  |-- StudentName: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)

# %%
df.select("StudentName","Age").show(10)
# Out:
# +------------------+---+
# |       StudentName|Age|
# +------------------+---+
# |       Dean Wilson| 19|
# |    Kirsten Garner| 23|
# |   Jessica Stewart| 19|
# |    Jacob Mitchell| 19|
# |    Elizabeth Lowe| 19|
# |    Janice Huffman| 24|
# |Christina Richards| 20|
# |      James Cuevas| 18|
# |        Carol Wood| 19|
# |      Joann Taylor| 25|
# +------------------+---+
# only showing top 10 rows

# %%
df.select("*").show(5)
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# |    StudentName|Age|Grade|Gender|             Address|               City|       State|      Country|               Email|               Phone|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# |    Dean Wilson| 19|    E|  Male|217 Charles Trail...|        Lake Andrew|     Georgia|Liechtenstein|marilyn71@example...|    489-336-6475x408|
# | Kirsten Garner| 23|    C|  Male|239 Herrera Knoll...|   South Janethaven|      Alaska|    Indonesia| imercer@example.org|001-537-249-3192x174|
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|        Haiti|christinereynolds...|        948-417-3494|
# | Jacob Mitchell| 19|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|  Philippines| laura50@example.com|001-854-656-0336x...|
# | Elizabeth Lowe| 19|    D|  Male|0582 Daugherty Dr...|           Lunaview|   Wisconsin|     Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.select(df.columns[0:4]).show()
# Out:
# +-------------------+---+-----+------+
# |        StudentName|Age|Grade|Gender|
# +-------------------+---+-----+------+
# |        Dean Wilson| 19|    E|  Male|
# |     Kirsten Garner| 23|    C|  Male|
# |    Jessica Stewart| 19|    B|Female|
# |     Jacob Mitchell| 19|    B|Female|
# |     Elizabeth Lowe| 19|    D|  Male|
# |     Janice Huffman| 24|    A|Female|
# | Christina Richards| 20|    C|  Male|
# |       James Cuevas| 18|    A|  Male|
# |         Carol Wood| 19|    B|  Male|
# |       Joann Taylor| 25|    D|Female|
# |Jacqueline Chandler| 23|    D|  Male|
# | Danielle Carpenter| 21|    D|  Male|
# |    Anthony Jackson| 19|    C|  Male|
# |      Angela Gentry| 22|    A|Female|
# |      Austin Gordon| 19|    D|  Male|
# |           Eric Lee| 21|    C|Female|
# |       Deborah Nash| 20|    C|Female|
# |         Aaron Kirk| 18|    C|Female|
# |        John Garcia| 25|    B|  Male|
# |      Jeremy Medina| 23|    C|Female|
# +-------------------+---+-----+------+
# only showing top 20 rows

# %%
df2=df.withColumn("Age",col("Age").cast("String"))

# %%
df2.printSchema()
# Out:
# root
#  |-- StudentName: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)

# %%
df2 = df2.withColumn("Age",col("Age").cast("integer"))

# %%
# Adding value to exsiting column value by 10
df2=df2.withColumn("Age",col("Age")+10)

# %%
df2.show(5)
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# |    StudentName|Age|Grade|Gender|             Address|               City|       State|      Country|               Email|               Phone|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# |    Dean Wilson| 29|    E|  Male|217 Charles Trail...|        Lake Andrew|     Georgia|Liechtenstein|marilyn71@example...|    489-336-6475x408|
# | Kirsten Garner| 33|    C|  Male|239 Herrera Knoll...|   South Janethaven|      Alaska|    Indonesia| imercer@example.org|001-537-249-3192x174|
# |Jessica Stewart| 29|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|        Haiti|christinereynolds...|        948-417-3494|
# | Jacob Mitchell| 29|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|  Philippines| laura50@example.com|001-854-656-0336x...|
# | Elizabeth Lowe| 29|    D|  Male|0582 Daugherty Dr...|           Lunaview|   Wisconsin|     Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df=df.withColumn("Marks",col("Age")+15)
df.select("StudentName","Marks").show(5)
# Out:
# +---------------+-----+
# |    StudentName|Marks|
# +---------------+-----+
# |    Dean Wilson|   34|
# | Kirsten Garner|   38|
# |Jessica Stewart|   34|
# | Jacob Mitchell|   34|
# | Elizabeth Lowe|   34|
# +---------------+-----+
# only showing top 5 rows

# %%
df= df.withColumn("Mob_no",lit(840980422))
df.select('StudentName',"Mob_no").show(5)
# Out:
# +---------------+---------+
# |    StudentName|   Mob_no|
# +---------------+---------+
# |    Dean Wilson|840980422|
# | Kirsten Garner|840980422|
# |Jessica Stewart|840980422|
# | Jacob Mitchell|840980422|
# | Elizabeth Lowe|840980422|
# +---------------+---------+
# only showing top 5 rows

# %%
df = df.withColumn("Marks", col("Marks") + 10).withColumn("Author", lit("tanya"))
df.select("StudentName", "Marks", "Author").show(5)
# Out:
# +---------------+-----+------+
# |    StudentName|Marks|Author|
# +---------------+-----+------+
# |    Dean Wilson|   44| tanya|
# | Kirsten Garner|   48| tanya|
# |Jessica Stewart|   44| tanya|
# | Jacob Mitchell|   44| tanya|
# | Elizabeth Lowe|   44| tanya|
# +---------------+-----+------+
# only showing top 5 rows

# %%
df=df.withColumnRenamed("StudentName","Student_name")
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+------+
# |   Student_name|Age|Grade|Gender|             Address|               City|       State|      Country|               Email|               Phone|Marks|   Mob_no|Author|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+------+
# |    Dean Wilson| 19|    E|  Male|217 Charles Trail...|        Lake Andrew|     Georgia|Liechtenstein|marilyn71@example...|    489-336-6475x408|   44|840980422| tanya|
# | Kirsten Garner| 23|    C|  Male|239 Herrera Knoll...|   South Janethaven|      Alaska|    Indonesia| imercer@example.org|001-537-249-3192x174|   48|840980422| tanya|
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|        Haiti|christinereynolds...|        948-417-3494|   44|840980422| tanya|
# | Jacob Mitchell| 19|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|  Philippines| laura50@example.com|001-854-656-0336x...|   44|840980422| tanya|
# | Elizabeth Lowe| 19|    D|  Male|0582 Daugherty Dr...|           Lunaview|   Wisconsin|     Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|   44|840980422| tanya|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+------+
# only showing top 5 rows

# %%
df = df.withColumnRenamed("Author","Author_of_data").withColumnRenamed("Address","Full_address")
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+--------------+
# |   Student_name|Age|Grade|Gender|        Full_address|               City|       State|      Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+--------------+
# |    Dean Wilson| 19|    E|  Male|217 Charles Trail...|        Lake Andrew|     Georgia|Liechtenstein|marilyn71@example...|    489-336-6475x408|   44|840980422|         tanya|
# | Kirsten Garner| 23|    C|  Male|239 Herrera Knoll...|   South Janethaven|      Alaska|    Indonesia| imercer@example.org|001-537-249-3192x174|   48|840980422|         tanya|
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|        Haiti|christinereynolds...|        948-417-3494|   44|840980422|         tanya|
# | Jacob Mitchell| 19|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|  Philippines| laura50@example.com|001-854-656-0336x...|   44|840980422|         tanya|
# | Elizabeth Lowe| 19|    D|  Male|0582 Daugherty Dr...|           Lunaview|   Wisconsin|     Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|   44|840980422|         tanya|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 5 rows

# %%
df.select(col("Age").alias("Student_age")).show(5)
# Out:
# +-----------+
# |Student_age|
# +-----------+
# |         19|
# |         23|
# |         19|
# |         19|
# |         19|
# +-----------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Student_name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Full_address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- Marks: integer (nullable = true)
#  |-- Mob_no: integer (nullable = false)
#  |-- Author_of_data: string (nullable = false)

# %%
df.filter(df.Gender == "Female").show()
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |   Student_name|Age|Grade|Gender|        Full_address|               City|       State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +---------------+---+-----+------+--------------------+-------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|               Haiti|christinereynolds...|        948-417-3494|   44|840980422|         tanya|
# | Jacob Mitchell| 19|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|         Philippines| laura50@example.com|001-854-656-0336x...|   44|840980422|         tanya|
# | Janice Huffman| 24|    A|Female|8813 Whitney Ferr...|   Christophermouth|    Illinois|              Jersey| maria72@example.com|       (225)945-1351|   49|840980422|         tanya|
# |   Joann Taylor| 25|    D|Female|802 Kelly Dale\nF...|      Martinezmouth|    Colorado|           Swaziland| xvaughn@example.net|        863.328.0443|   50|840980422|         tanya|
# |  Angela Gentry| 22|    A|Female|9576 Mitchell Pin...|   South Monicafort|     Montana|               China|   rwong@example.org|   (938)790-1162x007|   47|840980422|         tanya|
# |       Eric Lee| 21|    C|Female|USNS Sutton\nFPO ...|  New Michelleburgh|      Alaska|          Kazakhstan|jstevens@example.com|          6855654997|   46|840980422|         tanya|
# |   Deborah Nash| 20|    C|Female|Unit 6579 Box 402...|           North Jo|     Indiana|            Botswana|webbelizabeth@exa...|  (913)730-8931x1908|   45|840980422|         tanya|
# |     Aaron Kirk| 18|    C|Female|USCGC Gibbs\nFPO ...|          Carolfurt|     Georgia|               Italy|cohenjeffrey@exam...|   501.252.0802x1575|   43|840980422|         tanya|
# |  Jeremy Medina| 23|    C|Female|74738 Hendricks E...|        Kentchester|    Maryland|                Iraq|smithmatthew@exam...|    546.707.0223x741|   48|840980422|         tanya|
# | Tammy Sullivan| 24|    A|Female|7005 Jacqueline E...|         Lake Kelli|   Minnesota|               India| wanda37@example.org|  978-745-5936x15633|   49|840980422|         tanya|
# |Christina Smith| 23|    B|Female|23763 Justin Port...|    Penningtonhaven|    Colorado|Lao People's Demo...|  hsalas@example.com|    520.863.8635x254|   48|840980422|         tanya|
# |  Rachel Murphy| 25|    E|Female|10608 Powell Caus...|          Rubenbury|     Wyoming|Holy See (Vatican...|stephaniefischer@...|   427.789.5707x6579|   50|840980422|         tanya|
# |  Brooke Moreno| 22|    D|Female|73854 Tara Trail ...|  Port Cynthiaville|     Vermont|           Sri Lanka|doughertymichael@...|        749.445.1944|   47|840980422|         tanya|
# |  Anthony Perez| 22|    D|Female|106 Brian Ways\nN...|       North Travis|        Iowa|          Mauritania|qgallagher@exampl...|   (695)619-7009x764|   47|840980422|         tanya|
# |Barry Rasmussen| 20|    B|Female|3796 Allen Corner...|       Martinezstad|     Montana|   Wallis and Futuna|owallace@example.com|  (321)494-4052x0894|   45|840980422|         tanya|
# |   William Kidd| 21|    E|Female|973 Rick Lake\nVe...|       East Matthew|    Delaware|               Yemen|sarahcolon@exampl...|+1-431-919-2530x6...|   46|840980422|         tanya|
# |   Adrian Gates| 22|    C|Female|2862 Mcintosh Wel...| Lake Alexanderberg|    Missouri|             Senegal| xlawson@example.net|       (826)316-5134|   47|840980422|         tanya|
# | Timothy Fowler| 18|    A|Female|906 Samantha Ford...|    New Darleneview|    Colorado|          Cape Verde|leslie40@example.org|    983-820-4208x181|   43|840980422|         tanya|
# |    Susan Wells| 20|    E|Female|USNS Smith\nFPO A...|      Domingueztown|   Tennessee|               Korea|   xwolf@example.org|        565-956-0552|   45|840980422|         tanya|
# |    Erica Allen| 19|    E|Female|PSC 3256, Box 657...|         East Bruce|       Texas|             Somalia|   hcarr@example.org|+1-875-574-1100x0296|   44|840980422|         tanya|
# +---------------+---+-----+------+--------------------+-------------------+------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 20 rows

# %%
df.select("Student_name","Gender","Age").filter(df.Gender == "Female").show(5)
# Out:
# +---------------+------+---+
# |   Student_name|Gender|Age|
# +---------------+------+---+
# |Jessica Stewart|Female| 19|
# | Jacob Mitchell|Female| 19|
# | Janice Huffman|Female| 24|
# |   Joann Taylor|Female| 25|
# |  Angela Gentry|Female| 22|
# +---------------+------+---+
# only showing top 5 rows

# %%
df.filter(col("Gender") == "Male").show(5)
# Out:
# +------------------+---+-----+------+--------------------+----------------+---------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |      Student_name|Age|Grade|Gender|        Full_address|            City|    State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +------------------+---+-----+------+--------------------+----------------+---------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |       Dean Wilson| 19|    E|  Male|217 Charles Trail...|     Lake Andrew|  Georgia|       Liechtenstein|marilyn71@example...|    489-336-6475x408|   44|840980422|         tanya|
# |    Kirsten Garner| 23|    C|  Male|239 Herrera Knoll...|South Janethaven|   Alaska|           Indonesia| imercer@example.org|001-537-249-3192x174|   48|840980422|         tanya|
# |    Elizabeth Lowe| 19|    D|  Male|0582 Daugherty Dr...|        Lunaview|Wisconsin|            Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|   44|840980422|         tanya|
# |Christina Richards| 20|    C|  Male|63986 Daniel Squa...|    West Melissa| Virginia|Saint Kitts and N...|josephcooper@exam...|+1-907-612-8386x6501|   45|840980422|         tanya|
# |      James Cuevas| 18|    A|  Male|059 Cole Neck\nRo...|    North Judith| Nebraska|             Uruguay|  ievans@example.org|     +1-406-305-8440|   43|840980422|         tanya|
# +------------------+---+-----+------+--------------------+----------------+---------+--------------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 5 rows

# %%
df.select("Student_name","Gender","Age").filter(col("Gender")=="Male").show()
# Out:
# +-------------------+------+---+
# |       Student_name|Gender|Age|
# +-------------------+------+---+
# |        Dean Wilson|  Male| 19|
# |     Kirsten Garner|  Male| 23|
# |     Elizabeth Lowe|  Male| 19|
# | Christina Richards|  Male| 20|
# |       James Cuevas|  Male| 18|
# |         Carol Wood|  Male| 19|
# |Jacqueline Chandler|  Male| 23|
# | Danielle Carpenter|  Male| 21|
# |    Anthony Jackson|  Male| 19|
# |      Austin Gordon|  Male| 19|
# |        John Garcia|  Male| 25|
# |       Brett Campos|  Male| 20|
# |        Tony Cooley|  Male| 18|
# |       Sierra Adams|  Male| 22|
# |      William Davis|  Male| 24|
# |     Michael Flores|  Male| 20|
# | Francisco Mcmillan|  Male| 19|
# |   Debra Miller PhD|  Male| 25|
# |      Brent Russell|  Male| 25|
# |    Kathleen Martin|  Male| 19|
# +-------------------+------+---+
# only showing top 20 rows

# %%
df.filter((df.Gender == "Male") & (df.Age == 24)).show(5)
# Out:
# +--------------+---+-----+------+--------------------+-------------+-------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# |  Student_name|Age|Grade|Gender|        Full_address|         City|        State|             Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|
# +--------------+---+-----+------+--------------------+-------------+-------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# | William Davis| 24|    A|  Male|688 Campos Union\...|West Brittany|        Maine|               Tonga| derek01@example.org|  918.409.1194x82320|   49|840980422|         tanya|
# | Ronnie Conley| 24|    D|  Male|121 Emily Mills\n...| Charleneview|   New Jersey|   Wallis and Futuna|heather00@example...|   621.736.4352x2153|   49|840980422|         tanya|
# | Joshua Romero| 24|    A|  Male|PSC 8704, Box 131...|   Jonesmouth|    Minnesota|Saint Vincent and...|   fmoss@example.net|  (721)697-7883x1402|   49|840980422|         tanya|
# |Michael Wilson| 24|    D|  Male|28166 Steven Key ...| Lake Crystal|New Hampshire|United States of ...| nstrong@example.org|+1-392-527-7033x6377|   49|840980422|         tanya|
# | Amanda Martin| 24|    B|  Male|389 Davis Gateway...| North Johnny| Pennsylvania|     Solomon Islands|richard53@example...|        343.915.8894|   49|840980422|         tanya|
# +--------------+---+-----+------+--------------------+-------------+-------------+--------------------+--------------------+--------------------+-----+---------+--------------+
# only showing top 5 rows

# %%
## Filtering using &(and) conditions
 
df.select("Student_name","Gender","Age").filter((df.Gender == "Male") & (df.Age == 24)).show(5)
# Out:
# +--------------+------+---+
# |  Student_name|Gender|Age|
# +--------------+------+---+
# | William Davis|  Male| 24|
# | Ronnie Conley|  Male| 24|
# | Joshua Romero|  Male| 24|
# |Michael Wilson|  Male| 24|
# | Amanda Martin|  Male| 24|
# +--------------+------+---+
# only showing top 5 rows

# %%
## Filtering using | (or) conditions
df.select("Student_name","Gender","Age").filter((df.Gender == "Male") | (df.Age == 24)).show(5)
# Out:
# +------------------+------+---+
# |      Student_name|Gender|Age|
# +------------------+------+---+
# |       Dean Wilson|  Male| 19|
# |    Kirsten Garner|  Male| 23|
# |    Elizabeth Lowe|  Male| 19|
# |    Janice Huffman|Female| 24|
# |Christina Richards|  Male| 20|
# +------------------+------+---+
# only showing top 5 rows

# %%
distinct_country = df.select("Country").distinct()
distinct_country.show()
# Out:
# +--------------------+
# |             Country|
# +--------------------+
# |         Philippines|
# |              Jersey|
# |             Eritrea|
# |                Iraq|
# |           Sri Lanka|
# |            Dominica|
# |               China|
# |               India|
# |         Isle of Man|
# |               Italy|
# |       Liechtenstein|
# |           Swaziland|
# |Saint Kitts and N...|
# |             Uruguay|
# |           Indonesia|
# |            Ethiopia|
# |       Faroe Islands|
# |            Botswana|
# |               Haiti|
# |          Kazakhstan|
# +--------------------+
# only showing top 20 rows

# %%
# Filtering using isin function

df.select("Student_name","Gender","Age","Country").filter(df.Country.isin(["Kazakhstan","Spain"])).show(5)
# Out:
# +---------------+------+---+----------+
# |   Student_name|Gender|Age|   Country|
# +---------------+------+---+----------+
# |       Eric Lee|Female| 21|Kazakhstan|
# |   Linda Walton|  Male| 18|     Spain|
# |Diana Robertson|  Male| 25|     Spain|
# |Natalie Marquez|  Male| 25|Kazakhstan|
# |    Carl Mooney|  Male| 22|Kazakhstan|
# +---------------+------+---+----------+

# %%
# filter all data whoes country starts with "K"

df.select("Student_name","Gender","Age","Country").filter(df.Country.startswith("K")).show(5)
# Out:
# +----------------+------+---+----------+
# |    Student_name|Gender|Age|   Country|
# +----------------+------+---+----------+
# |        Eric Lee|Female| 21|Kazakhstan|
# |     Susan Wells|Female| 20|     Korea|
# |Colin Cooley DDS|Female| 25|     Kenya|
# |Tiffany Thompson|Female| 24|     Korea|
# | Natalie Marquez|  Male| 25|Kazakhstan|
# +----------------+------+---+----------+
# only showing top 5 rows

# %%
# filter all data whoes country end with "K"

df.select("Student_name","Gender","Age","Country").filter(df.Country.endswith("n")).show(5)
# Out:
# +-------------------+------+---+-------------+
# |       Student_name|Gender|Age|      Country|
# +-------------------+------+---+-------------+
# |        Dean Wilson|  Male| 19|Liechtenstein|
# |Jacqueline Chandler|  Male| 23|  Isle of Man|
# |           Eric Lee|Female| 21|   Kazakhstan|
# |      Brent Russell|  Male| 25|     Pakistan|
# |       Linda Walton|  Male| 18|        Spain|
# +-------------------+------+---+-------------+
# only showing top 5 rows

# %%
# filter all data whoes country contains with "An"

df.select("Student_name","Gender","Age","Country").filter(df.Country.contains("An")).show(5)
# Out:
# +--------------+------+---+-------+
# |  Student_name|Gender|Age|Country|
# +--------------+------+---+-------+
# |Timothy Taylor|  Male| 18|Andorra|
# |  Derek Rivera|  Male| 21|Andorra|
# +--------------+------+---+-------+

# %%
# filter all data whoes country starts with "An" using(Like)

df.select("Student_name","Gender","Age","Country").filter(df.Country.like("An%")).show(5)
# Out:
# +--------------+------+---+-------+
# |  Student_name|Gender|Age|Country|
# +--------------+------+---+-------+
# |Timothy Taylor|  Male| 18|Andorra|
# |  Derek Rivera|  Male| 21|Andorra|
# +--------------+------+---+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- Student_name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Grade: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Full_address: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- Marks: integer (nullable = true)
#  |-- Mob_no: integer (nullable = false)
#  |-- Author_of_data: string (nullable = false)

# %%
df.select("Student_name","Marks").show(5)
# Out:
# +---------------+-----+
# |   Student_name|Marks|
# +---------------+-----+
# |    Dean Wilson|   44|
# | Kirsten Garner|   48|
# |Jessica Stewart|   44|
# | Jacob Mitchell|   44|
# | Elizabeth Lowe|   44|
# +---------------+-----+
# only showing top 5 rows

# %%
df = df.withColumn("Percentage",col("Marks")+20).withColumn("Total_marks",lit(120))
df.select("Student_name","Marks","Percentage","Total_marks").show(5)
# Out:
# +---------------+-----+----------+-----------+
# |   Student_name|Marks|Percentage|Total_marks|
# +---------------+-----+----------+-----------+
# |    Dean Wilson|   44|        64|        120|
# | Kirsten Garner|   48|        68|        120|
# |Jessica Stewart|   44|        64|        120|
# | Jacob Mitchell|   44|        64|        120|
# | Elizabeth Lowe|   44|        64|        120|
# +---------------+-----+----------+-----------+
# only showing top 5 rows

# %%
df=df.withColumn("Avg_marks",col("Marks")/col("Total_marks")*100)

df.select("Student_name","Marks","Percentage","Total_marks","Avg_marks").show(5)
# Out:
# +---------------+-----+----------+-----------+------------------+
# |   Student_name|Marks|Percentage|Total_marks|         Avg_marks|
# +---------------+-----+----------+-----------+------------------+
# |    Dean Wilson|   44|        64|        120|36.666666666666664|
# | Kirsten Garner|   48|        68|        120|              40.0|
# |Jessica Stewart|   44|        64|        120|36.666666666666664|
# | Jacob Mitchell|   44|        64|        120|36.666666666666664|
# | Elizabeth Lowe|   44|        64|        120|36.666666666666664|
# +---------------+-----+----------+-----------+------------------+
# only showing top 5 rows

# %%
df_check = df.select("Student_name","Percentage").filter(df.Percentage >= 50)

df_check.show()
# Out:
# +-------------------+----------+
# |       Student_name|Percentage|
# +-------------------+----------+
# |        Dean Wilson|        64|
# |     Kirsten Garner|        68|
# |    Jessica Stewart|        64|
# |     Jacob Mitchell|        64|
# |     Elizabeth Lowe|        64|
# |     Janice Huffman|        69|
# | Christina Richards|        65|
# |       James Cuevas|        63|
# |         Carol Wood|        64|
# |       Joann Taylor|        70|
# |Jacqueline Chandler|        68|
# | Danielle Carpenter|        66|
# |    Anthony Jackson|        64|
# |      Angela Gentry|        67|
# |      Austin Gordon|        64|
# |           Eric Lee|        66|
# |       Deborah Nash|        65|
# |         Aaron Kirk|        63|
# |        John Garcia|        70|
# |      Jeremy Medina|        68|
# +-------------------+----------+
# only showing top 20 rows

# %%
df.select("Student_name","marks","Percentage").filter(df.Percentage < 70).show()
# Out:
# +-------------------+-----+----------+
# |       Student_name|marks|Percentage|
# +-------------------+-----+----------+
# |        Dean Wilson|   44|        64|
# |     Kirsten Garner|   48|        68|
# |    Jessica Stewart|   44|        64|
# |     Jacob Mitchell|   44|        64|
# |     Elizabeth Lowe|   44|        64|
# |     Janice Huffman|   49|        69|
# | Christina Richards|   45|        65|
# |       James Cuevas|   43|        63|
# |         Carol Wood|   44|        64|
# |Jacqueline Chandler|   48|        68|
# | Danielle Carpenter|   46|        66|
# |    Anthony Jackson|   44|        64|
# |      Angela Gentry|   47|        67|
# |      Austin Gordon|   44|        64|
# |           Eric Lee|   46|        66|
# |       Deborah Nash|   45|        65|
# |         Aaron Kirk|   43|        63|
# |      Jeremy Medina|   48|        68|
# |     Tammy Sullivan|   49|        69|
# |       Brett Campos|   45|        65|
# +-------------------+-----+----------+
# only showing top 20 rows

# %%
# count all data from in dataframe
df.count()
# Out:
# Out[40]: 200

# %%
df.select("Country").distinct().show()
# Out:
# +--------------------+
# |             Country|
# +--------------------+
# |         Philippines|
# |              Jersey|
# |             Eritrea|
# |                Iraq|
# |           Sri Lanka|
# |            Dominica|
# |               China|
# |               India|
# |         Isle of Man|
# |               Italy|
# |       Liechtenstein|
# |           Swaziland|
# |Saint Kitts and N...|
# |             Uruguay|
# |           Indonesia|
# |            Ethiopia|
# |       Faroe Islands|
# |            Botswana|
# |               Haiti|
# |          Kazakhstan|
# +--------------------+
# only showing top 20 rows

# %%
df.filter(df.Country == "Eritrea").count()
# Out:
# Out[42]: 1

# %%
df.distinct().count()
# Out:
# Out[43]: 200

# %%
df.select("Student_name").distinct().show()
# Out:
# +-------------------+
# |       Student_name|
# +-------------------+
# |    Anthony Jackson|
# |     Elizabeth Lowe|
# |         Aaron Kirk|
# | Danielle Carpenter|
# | Christina Richards|
# |Jacqueline Chandler|
# |       Deborah Nash|
# |      Austin Gordon|
# |     Janice Huffman|
# |           Eric Lee|
# |      Angela Gentry|
# |     Jacob Mitchell|
# |        John Garcia|
# |     Kirsten Garner|
# |       Joann Taylor|
# |       James Cuevas|
# |    Jessica Stewart|
# |     Tammy Sullivan|
# |        Dean Wilson|
# |      Jeremy Medina|
# +-------------------+
# only showing top 20 rows

# %%
df=df.dropDuplicates(["Country"]).show()

# %%
df.show(5)
# Out:
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# |   Student_name|Age|Grade|Gender|        Full_address|               City|       State|      Country|               Email|               Phone|Marks|   Mob_no|Author_of_data|Percentage|Total_marks|         Avg_marks|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# |    Dean Wilson| 19|    E|  Male|217 Charles Trail...|        Lake Andrew|     Georgia|Liechtenstein|marilyn71@example...|    489-336-6475x408|   44|840980422|         tanya|        64|        120|36.666666666666664|
# | Kirsten Garner| 23|    C|  Male|239 Herrera Knoll...|   South Janethaven|      Alaska|    Indonesia| imercer@example.org|001-537-249-3192x174|   48|840980422|         tanya|        68|        120|              40.0|
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|          Port John|     Indiana|        Haiti|christinereynolds...|        948-417-3494|   44|840980422|         tanya|        64|        120|36.666666666666664|
# | Jacob Mitchell| 19|    B|Female|917 Garcia Falls\...|New Christopherstad|Rhode Island|  Philippines| laura50@example.com|001-854-656-0336x...|   44|840980422|         tanya|        64|        120|36.666666666666664|
# | Elizabeth Lowe| 19|    D|  Male|0582 Daugherty Dr...|           Lunaview|   Wisconsin|     Ethiopia|joshuaholt@exampl...|     +1-274-352-0813|   44|840980422|         tanya|        64|        120|36.666666666666664|
# +---------------+---+-----+------+--------------------+-------------------+------------+-------------+--------------------+--------------------+-----+---------+--------------+----------+-----------+------------------+
# only showing top 5 rows

# %%
df_unique_gender = df.dropDuplicates(['Gender'])
df_unique_gender.distinct().count()
df_unique_gender.distinct().show()
# Out:
# +---------------+---+-----+------+--------------------+-----------+-------+-------------+--------------------+----------------+-----+---------+--------------+----------+-----------+------------------+
# |   Student_name|Age|Grade|Gender|        Full_address|       City|  State|      Country|               Email|           Phone|Marks|   Mob_no|Author_of_data|Percentage|Total_marks|         Avg_marks|
# +---------------+---+-----+------+--------------------+-----------+-------+-------------+--------------------+----------------+-----+---------+--------------+----------+-----------+------------------+
# |Jessica Stewart| 19|    B|Female|78540 Hobbs Manor...|  Port John|Indiana|        Haiti|christinereynolds...|    948-417-3494|   44|840980422|         tanya|        64|        120|36.666666666666664|
# |    Dean Wilson| 19|    E|  Male|217 Charles Trail...|Lake Andrew|Georgia|Liechtenstein|marilyn71@example...|489-336-6475x408|   44|840980422|         tanya|        64|        120|36.666666666666664|
# +---------------+---+-----+------+--------------------+-----------+-------+-------------+--------------------+----------------+-----+---------+--------------+----------+-----------+------------------+

# %%
# sorting ascending order
df.select('Student_name',"Marks").sort("Marks").show(5)
# Out:
# +---------------+-----+
# |   Student_name|Marks|
# +---------------+-----+
# |Amanda Williams|   43|
# |  Joseph Murray|   43|
# |   Derek Hunter|   43|
# |   Adrian Lopez|   43|
# |  Michael Cross|   43|
# +---------------+-----+
# only showing top 5 rows

# %%
# sorting ascending order
df.select('Student_name',"Marks").orderBy("Marks").show(5)
# Out:
# +---------------+-----+
# |   Student_name|Marks|
# +---------------+-----+
# |     Lisa Allen|   43|
# |  Joseph Murray|   43|
# |   James Cuevas|   43|
# |   Adrian Lopez|   43|
# |Amanda Williams|   43|
# +---------------+-----+
# only showing top 5 rows

# %%
# sorting descending order
df.select('Student_name',"Marks").sort(df.Marks.desc()).show(5)
# Out:
# +----------------+-----+
# |    Student_name|Marks|
# +----------------+-----+
# |  Rodney Johnson|   50|
# |Debra Miller PhD|   50|
# |    Chelsea Rose|   50|
# |   Brent Russell|   50|
# |    Joann Taylor|   50|
# +----------------+-----+
# only showing top 5 rows

# %%
# sorting descending order
df.select('Student_name',"Marks").orderBy(df.Marks.desc()).show(5)
# Out:
# +----------------+-----+
# |    Student_name|Marks|
# +----------------+-----+
# |    Chelsea Rose|   50|
# |   Jasmine Brown|   50|
# |  Rodney Johnson|   50|
# |  Adam Phelps MD|   50|
# |Debra Miller PhD|   50|
# +----------------+-----+
# only showing top 5 rows

# %%
# Gender wise sum of marks
df.groupBy("Gender").sum("Marks").show()

# Gender wise count 
df.groupBy("Gender").count().show()

# Gender wise max of marks
df.groupBy("Gender").max("Marks").show()

# Gender wise min of marks
df.groupBy("Gender").min("Marks").show()

# Gender wise avg of marks
df.groupBy("Gender").avg("Marks").show()
# Out:
# +------+----------+
# |Gender|sum(Marks)|
# +------+----------+
# |Female|      3722|
# |  Male|      5590|
# +------+----------+
#
# +------+-----+
# |Gender|count|
# +------+-----+
# |Female|   80|
# |  Male|  120|
# +------+-----+
#
# +------+----------+
# |Gender|max(Marks)|
# +------+----------+
# |Female|        50|
# |  Male|        50|
# +------+----------+
#
# +------+----------+
# |Gender|min(Marks)|
# +------+----------+
# |Female|        43|
# |  Male|        43|
# +------+----------+
#
# +------+------------------+
# |Gender|        avg(Marks)|
# +------+------------------+
# |Female|            46.525|
# |  Male|46.583333333333336|
# +------+------------------+
#
# +------+------------------+
# |Gender|        avg(Marks)|
# +------+------------------+
# |Female|            46.525|
# |  Male|46.583333333333336|
# +------+------------------+

# %%
# Gender wise count
df.groupBy("Gender").count().show()

# Gender,Country wise count
df.groupBy("Country","Gender").count().show()
# Out:
# +------+-----+
# |Gender|count|
# +------+-----+
# |Female|   80|
# |  Male|  120|
# +------+-----+
#
# +-------------+------+-----+
# |      Country|Gender|count|
# +-------------+------+-----+
# |  Philippines|Female|    1|
# |Faroe Islands|  Male|    1|
# |  Isle of Man|  Male|    2|
# |    Swaziland|Female|    2|
# |        Italy|Female|    1|
# |       France|  Male|    1|
# |      Moldova|  Male|    1|
# |      Eritrea|  Male|    1|
# |Liechtenstein|  Male|    1|
# |        Tonga|  Male|    1|
# |     Ethiopia|  Male|    2|
# |        India|Female|    1|
# |         Iraq|Female|    2|
# | Sierra Leone|  Male|    2|
# |        Haiti|Female|    1|
# |       Jersey|Female|    2|
# |      Uruguay|  Male|    1|
# |     Dominica|  Male|    2|
# |Cote d'Ivoire|  Male|    4|
# |    Indonesia|  Male|    1|
# +-------------+------+-----+
# only showing top 20 rows

# %%
df.groupBy("Gender").agg(count("*").alias("Total_count"),sum("Marks").alias("Sum_of_marks"),avg("Marks").alias("Avg_of_marks"),min("Marks").alias("Min_of_marks"),max("Marks").alias("max_of_marks")).show()
# Out:
# +------+-----------+------------+------------------+------------+------------+
# |Gender|Total_count|Sum_of_marks|      Avg_of_marks|Min_of_marks|max_of_marks|
# +------+-----------+------------+------------------+------------+------------+
# |Female|         80|        3722|            46.525|          43|          50|
# |  Male|        120|        5590|46.583333333333336|          43|          50|
# +------+-----------+------------+------------------+------------+------------+
