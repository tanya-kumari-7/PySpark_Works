# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField,IntegerType,StringType
from pyspark.sql.functions import col,lit,sum,avg,max,min,mean,count,when,udf

spark = SparkSession.builder\
    .appName("Mini_project_o1")\
        .getOrCreate()

# %%
schema = StructType([
    StructField("employee_id", StringType(), True),
    StructField("employee_name", StringType(), True),
    StructField("department", StringType(), True),
    StructField("state", StringType(), True),
    StructField("salary", IntegerType(), True),
    StructField("age", IntegerType(), True),
    StructField("bonus", IntegerType(), True)
])

data = [
("1000", "Nitz Leif", "Marketing", "CA",6131,26,543),
("1001", "Melissia Dedman", "Finance", "AK",4027,43,1290),
("1002", "Rudolph Barringer", "HR", "LA",3122,43,1445),
("1003", "Tamra Amber", "Accounts", "AK",5717,47,1291),
("1004", "Mullan Nitz", "Purchasing", "CA",5685,34,1394),
("1005", "Zollner Karie", "Accounts", "CA",2843,27,1078),
("1006", "Kaczorowski Zollner", "Sales", "CA",7201,21,1834),
("1007", "Nakano Locust", "Marketing", "LA",3444,23,1823),
("1008", "Recalde Kensinger", "Accounts", "LA",3704,48,1330),
("1009", "Imai Hallie", "Accounts", "AK",5061,38,1557),
("1010", "Debroah Gallman", "Accounts", "NY",9308,35,817),
("1011", "Barringer Escoto", "Purchasing", "WA",1685,49,1706),
("1012", "Soules Coogan", "Accounts", "AK",8330,43,1914),
("1013", "Luisa Suzanne", "Accounts", "CA",1151,37,1095),
("1014", "Marvis Cobian", "Purchasing", "NY",5061,41,1765),
("1015", "Cobian Kensinger", "Sales", "LA",1983,21,632),
("1016", "Gilma Margret", "Marketing", "CA",2919,45,1762),
("1017", "Ellingsworth Ilana", "Accounts", "WA",9614,26,1964),
("1018", "Vankirk Jacquelyne", "Purchasing", "NY",8636,47,1192),
("1019", "Zollner Juliana", "HR", "NY",9739,30,1119),
("1020", "Megan Gallman", "Finance", "CA",8628,27,990),
("1021", "Gilma Imai", "Purchasing", "CA",9236,25,1703),
("1022", "Jacquelyne Hanh", "Accounts", "AK",7310,38,1866),
("1023", "Trena Clemencia", "Finance", "CA",7275,23,1005),
("1024", "Dedman Jere", "HR", "WA",1385,32,1358),
("1025", "Dionne Lemaster", "Sales", "AK",5134,48,1356),
("1026", "Janey Ilana", "Purchasing", "AK",2338,42,1311),
("1027", "Tyree Soules", "Finance", "AK",2810,45,1510),
("1028", "Debroah Kreamer", "Sales", "AK",6051,25,895),
("1029", "Frisina Gallman", "HR", "CA",2786,38,1512),
("1030", "Trena Benz", "Accounts", "NY",4376,49,1624),
("1031", "Suzanne Trena", "Finance", "AK",3039,20,761),
("1032", "Antonio Casimira", "HR", "NY",3212,24,1008),
("1033", "Amber Richter", "Accounts", "LA",7624,38,1580),
("1034", "Layla Antonina", "Sales", "CA",9129,37,1619),
("1035", "Vivan Sifford", "Finance", "NY",1129,35,1261),
("1036", "Mullan Trena", "Sales", "WA",7370,30,1848),
("1037", "Herder Nitz", "Finance", "AK",1677,25,579),
("1038", "Dionne Hanh", "Accounts", "WA",1956,30,1498),
("1039", "Dynes Katlyn", "Accounts", "AK",3039,48,834),
("1040", "Tamra Laub", "Sales", "LA",9587,28,1240),
("1041", "Vivan Kall", "Purchasing", "NY",1928,45,718),
("1042", "Jaclyn Layla", "HR", "NY",7541,25,1289),
("1043", "Byrge Yukiko", "Sales", "WA",8371,26,1945),
("1044", "Escoto Kohn", "Purchasing", "NY",2268,44,1533),
("1045", "Kaczorowski Dynes", "Purchasing", "NY",3901,42,1802),
("1046", "Zollner Kensinger", "Sales", "WA",6636,20,1208),
("1047", "Exie Georgeanna", "Finance", "WA",4651,41,1794),
("1048", "Melissia Leonel", "Marketing", "CA",3864,39,741),
("1049", "Ellingsworth Lonergan", "Accounts", "WA",4503,37,1090),
("1050", "Melissia Imai", "Accounts", "CA",8926,37,1149),
("1051", "Gallman Bergren", "Marketing", "AK",4980,43,1046),
("1052", "Antonio Ruzicka", "Finance", "AK",2751,22,990),
("1053", "Fender Yessenia", "Marketing", "CA",7029,23,715),
("1054", "Lisabeth Gallman", "Marketing", "NY",2143,37,1623),
("1055", "Nakano Clune", "Accounts", "CA",7594,40,809),
("1056", "Byrge Lisabeth", "Sales", "LA",2284,41,1022),
("1057", "Yukiko Fender", "Purchasing", "LA",7113,20,1814),
("1058", "Clune Norene", "Finance", "AK",1605,49,801),
("1059", "Suzanne Gilma", "Purchasing", "NY",2092,37,1840),
("1060", "Rudolph Grigg", "Purchasing", "LA",6072,23,822),
("1061", "Charlie Antonina", "Accounts", "WA",2927,40,1043),
("1062", "Megan Vankirk", "Marketing", "CA",8737,45,1847),
("1063", "Vivan Jacquelyne", "Marketing", "LA",9974,35,823),
("1064", "Locust Dedman", "Marketing", "WA",9101,26,1657),
("1065", "Luisa Jere", "Sales", "NY",7870,36,1866),
("1066", "Locust Louann", "Sales", "LA",7719,29,1698),
("1067", "Ruzicka Nena", "Marketing", "NY",2379,40,831),
("1068", "Ilana Deandre", "Sales", "WA",3393,20,1936),
("1069", "Figueras Sifford", "HR", "WA",8815,45,872),
("1070", "Janine Mayeda", "Finance", "WA",7044,25,1870),
("1071", "Norene Marvis", "Marketing", "NY",4713,30,968),
("1072", "Janine Fender", "HR", "CA",7572,28,1139),
("1073", "Herder Gallman", "Finance", "NY",1988,31,1402),
("1074", "Rocha Dionne", "Accounts", "CA",3470,49,706),
("1075", "Trena Melissia", "HR", "LA",2969,31,1653),
("1076", "Casimira Katlyn", "Finance", "WA",5966,22,1330),
("1077", "Vivan Locust", "HR", "NY",8389,34,1313),
("1078", "Tenenbaum Suzanne", "Finance", "AK",3426,21,1790),
("1079", "Grigg Debroah", "Finance", "NY",5728,28,1146),
("1080", "Phylicia Nena", "Accounts", "WA",9506,26,1313),
("1081", "Recalde Reardon", "Purchasing", "LA",4273,27,1529),
("1082", "Nena Rocha", "Finance", "NY",3417,25,1647),
("1083", "Benz Melvina", "HR", "NY",2558,43,1151),
("1084", "Clemencia Locust", "Finance", "CA",9017,24,1577),
("1085", "Karie Sifford", "Sales", "NY",3207,23,871),
("1086", "Villela Dedman", "Purchasing", "WA",5072,22,684),
("1087", "Leif Lemaster", "Finance", "NY",8642,45,1782),
("1088", "Imai Locust", "Sales", "NY",9982,49,1809),
("1089", "Herder Villela", "Marketing", "NY",2671,32,632),
("1090", "Clemencia Rudolph", "Finance", "NY",1296,50,1209),
("1091", "Nitz Mcmillion", "Sales", "WA",6095,21,1940),
("1092", "Ullery Juliana", "Marketing", "LA",5745,26,1978),
("1093", "Janey Amber", "Finance", "LA",7005,25,1842),
("1094", "Antonio Mullan", "Marketing", "AK",7138,30,1630),
("1095", "Toussaint Layla", "Marketing", "LA",4598,22,1958),
("1096", "Coogan Toussaint", "Marketing", "NY",7109,38,603),
("1097", "Bergren Dedman", "Sales", "CA",5192,33,1673),
("1098", "Dedman Laub", "Sales", "AK",5674,22,1511),
("1099", "Zollner Marvis", "Purchasing", "CA",4230,50,951),
("1100", "Ellingsworth Melissia", "Finance", "NY",7845,32,1358),
("1101", "Escoto Clemencia", "Marketing", "WA",2038,40,1146),
("1102", "Lemaster Juliana", "Finance", "AK",4614,29,526),
("1103", "Amber Exie", "Purchasing", "AK",7963,29,1029),
("1104", "Antonio Clemencia", "HR", "LA",7929,33,1256),
("1105", "Katlyn Casimira", "Sales", "NY",7447,32,612),
("1106", "Reardon Kall", "Purchasing", "LA",6222,25,677),
("1107", "Nena Cobian", "Purchasing", "WA",5362,28,1409),
("1108", "Fender Mayeda", "Purchasing", "WA",6022,43,1692),
("1109", "Lonergan Trena", "Purchasing", "WA",2286,37,1754),
("1110", "Toussaint Tyree", "HR", "NY",3677,26,1573),
("1111", "Margret Reighard", "HR", "CA",6592,22,1396),
("1112", "Stanford Durio", "Purchasing", "WA",9123,25,732),
("1113", "Figueras Escoto", "Purchasing", "WA",3516,43,1364),
("1114", "Locust Antonina", "Sales", "WA",2842,40,1689),
("1115", "Trena Nitz", "Marketing", "CA",9255,41,532),
("1116", "Norene Kensinger", "Accounts", "AK",5206,38,1791),
("1117", "Grigg Tyree", "Sales", "WA",8139,33,1545),
("1118", "Kohn Antonina", "Sales", "CA",9311,48,1229),
("1119", "Toussaint Deandre", "Purchasing", "WA",3270,45,1744),
("1120", "Luisa Deandre", "Accounts", "CA",2792,34,1833),
("1121", "Toussaint Nitz", "Sales", "WA",6358,27,1967),
("1122", "Benz Coogan", "Accounts", "CA",8221,36,1374),
("1123", "Antonio Juliana", "Sales", "NY",3478,32,1338),
("1124", "Deandre Grigg", "Purchasing", "LA",6721,28,1399),
("1125", "Richter Escoto", "HR", "LA",2143,38,1078),
("1126", "Norene Mayeda", "Accounts", "LA",3100,50,1333),
("1127", "Escoto Gilma", "Finance", "NY",3426,41,1285),
("1128", "Jacquelyne Kreamer", "Finance", "CA",7353,31,1272),
("1129", "Kall Karie", "HR", "CA",1716,34,1254),
("1130", "Kohn Figueras", "Purchasing", "CA",1105,27,908),
("1131", "Louann Katlyn", "HR", "LA",8352,39,500),
("1132", "Juliana Trena", "Marketing", "LA",3253,25,751),
("1133", "Soules Mckey", "HR", "NY",3555,45,1752),
("1134", "Melvina Clemencia", "Sales", "CA",6514,35,941),
("1135", "Antonio Antonina", "Marketing", "NY",2835,27,1295),
("1136", "Jaclyn Baros", "Sales", "LA",1699,48,1094),
("1137", "Norene Antonina", "HR", "WA",8880,24,1946),
("1138", "Layla Tenenbaum", "Accounts", "CA",1461,32,1092),
("1139", "Leonel Yukiko", "Purchasing", "AK",7344,39,505),
("1140", "Layla Karie", "HR", "LA",2014,37,1465),
("1141", "Byrge Rocha", "Finance", "LA",6636,20,913),
("1142", "Hanh Cobian", "Marketing", "LA",7639,24,807),
("1143", "Nakano Mcmillion", "Accounts", "NY",1716,32,1762),
("1144", "Herder Baros", "Finance", "AK",1053,32,1941),
("1145", "Marvis Ruzicka", "Finance", "AK",4728,37,1177),
("1146", "Escoto Ilana", "Marketing", "AK",1327,44,1639),
("1147", "Kohn Louann", "Accounts", "CA",3401,31,676),
("1148", "Janey Suzanne", "Finance", "CA",1486,33,724),
("1149", "Escoto Gallman", "Finance", "CA",3175,28,883),
("1150", "Mcmillion Nakano", "Marketing", "CA",1787,37,1612),
("1151", "Barringer Kreamer", "Sales", "LA",5407,38,866),
("1152", "Cobian Hanh", "Marketing", "AK",9355,28,1070),
("1153", "Tiffani Jaclyn", "Purchasing", "CA",5315,33,1796),
("1154", "Sifford Cobian", "Sales", "AK",1861,20,1521),
("1155", "Zollner Mullan", "Accounts", "AK",5295,27,869),
("1156", "Jaclyn Dionne", "Marketing", "AK",3433,20,1489),
("1157", "Benz Hanh", "Purchasing", "AK",2858,32,1430),
("1158", "Melvina Benz", "Sales", "CA",2522,29,1984),
("1159", "Layla Kaczorowski", "Finance", "CA",8942,21,1759),
("1160", "Soules Baros", "Sales", "LA",7065,33,754),
("1161", "Georgeanna Laub", "Finance", "NY",2469,26,1679),
("1162", "Leif Exie", "Marketing", "AK",7048,24,1918),
("1163", "Ilana Grigg", "HR", "LA",7869,44,1329),
("1164", "Gallman Nakano", "Sales", "CA",6813,47,857),
("1165", "Luisa Grigg", "Purchasing", "AK",9297,48,1545),
("1166", "Tenenbaum Katlyn", "Sales", "AK",4684,43,1293),
("1167", "Antonio Jaclyn", "Purchasing", "LA",7128,26,1700),
("1168", "Amber Trena", "Purchasing", "LA",6015,31,1150),
("1169", "Kreamer Shandra", "HR", "WA",4968,46,889),
("1170", "Fender Coogan", "Marketing", "AK",1151,50,1845),
("1171", "Luisa Villela", "HR", "WA",8589,41,1986),
("1172", "Megan Reighard", "Accounts", "WA",8102,20,1535),
("1173", "Lemaster Melissia", "Marketing", "NY",5171,38,1157),
("1174", "Laub Kaczorowski", "Marketing", "NY",3130,41,949),
("1175", "Durio Tenenbaum", "Finance", "NY",2253,42,1684),
("1176", "Nena Nakano", "Finance", "LA",7628,32,671),
("1177", "Marvis Amber", "Sales", "CA",6890,29,1407),
("1178", "Fender Imai", "Finance", "AK",5930,34,566),
("1179", "Megan Antonina", "Purchasing", "WA",1844,25,1723),
("1180", "Juliana Grigg", "Finance", "NY",8178,42,1617),
("1181", "Gallman Ilana", "Finance", "LA",6480,45,1823),
("1182", "Soules Recalde", "Sales", "LA",6525,34,1517),
("1183", "Lonergan Bergren", "HR", "NY",8175,46,1730),
("1184", "Fender Dionne", "Sales", "LA",4963,26,1190),
("1185", "Casimira Kreamer", "Marketing", "CA",6110,50,761),
("1186", "Tyree Recalde", "Accounts", "NY",5932,50,1144),
("1187", "Gilma Hallie", "Finance", "CA",2502,50,1882),
("1188", "Toussaint Karie", "Purchasing", "WA",6829,32,1238),
("1189", "Imai Stanford", "Finance", "LA",4649,37,1754),
("1190", "Escoto Charlie", "Finance", "AK",5716,33,714),
("1191", "Reighard Herder", "Finance", "AK",7609,47,615),
("1192", "Karie Ullery", "Purchasing", "WA",3306,20,1877),
("1193", "Harrison Ullery", "Finance", "WA",1846,29,663),
("1194", "Frisina Hanh", "Purchasing", "AK",2779,28,1161),
("1195", "Leonel Rudolph", "Accounts", "CA",6388,43,1663),
("1196", "Kensinger Debroah", "Marketing", "CA",2188,41,1163),
("1197", "Baros Shandra", "HR", "LA",8352,40,1975),
("1198", "Kreamer Vankirk", "HR", "AK",4661,37,1219),
("1199", "Ullery Hanh", "Purchasing", "AK",9284,20,1964),
("1200", "Gallman Deandre", "Sales", "CA",9940,40,1226),
("1201", "Kall Nena", "HR", "AK",6540,20,1387),
("1202", "Ruzicka Zollner", "Marketing", "LA",8425,40,998),
("1203", "Yukiko Debroah", "Purchasing", "LA",8298,43,1777),
("1204", "Durio Herder", "Sales", "CA",4242,37,1334),
("1205", "Rocha Melvina", "Marketing", "LA",2363,22,831),
("1206", "Tenenbaum Marvis", "Accounts", "AK",4937,40,919),
("1207", "Charlie Barringer", "Accounts", "AK",1434,42,1363),
("1208", "Toussaint Villela", "Purchasing", "WA",5264,45,567),
("1209", "Megan Vivan", "Accounts", "AK",2786,20,1593),
("1210", "Dynes Clemencia", "Finance", "WA",3922,47,1075),
("1211", "Lemaster Debroah", "Finance", "AK",7957,47,1062),
("1212", "Shandra Trena", "Purchasing", "CA",1116,23,1539),
("1213", "Ullery Barringer", "Sales", "CA",5716,32,739),
("1214", "Marvis Lisabeth", "Finance", "NY",1062,49,639),
("1215", "Tiffani Benz", "Finance", "NY",1665,41,1969),
("1216", "Mcmillion Stanford", "HR", "LA",8199,43,1722),
("1217", "Escoto Megan", "Sales", "WA",5056,43,908),
("1218", "Tamra Janine", "Finance", "CA",7799,36,1838),
("1219", "Larry Tiffani", "Purchasing", "AK",5831,34,1081),
("1220", "Nitz Ilana", "Finance", "NY",2443,50,1342),
("1221", "Hanh Kall", "Accounts", "AK",4840,23,594),
("1222", "Rocha Melissia", "HR", "LA",2375,39,1741),
("1223", "Fender Janey", "Marketing", "WA",1356,43,901),
("1224", "Sifford Coogan", "Sales", "WA",3857,38,881),
("1225", "Ellingsworth Byrge", "Finance", "AK",8933,31,1041),
("1226", "Tyree Georgeanna", "Purchasing", "WA",5694,22,1044),
("1227", "Shandra Exie", "Purchasing", "LA",5397,20,659),
("1228", "Juliana Coogan", "Purchasing", "LA",9675,37,1930),
("1229", "Tamra Deandre", "Accounts", "WA",1007,44,777),
("1230", "Ilana Dionne", "Sales", "CA",2976,21,1133),
("1231", "Hanh Laub", "Sales", "AK",6520,23,1132),
("1232", "Kreamer Clemencia", "Marketing", "NY",4086,42,1952),
("1233", "Tamra Figueras", "Finance", "AK",1618,39,744),
("1234", "Suzanne Ilana", "Marketing", "AK",7767,43,1541),
("1235", "Ilana Georgeanna", "Finance", "LA",4962,25,600),
("1236", "Lisabeth Nitz", "Accounts", "CA",6894,29,1640),
("1237", "Mckey Phylicia", "Accounts", "CA",2510,22,1415),
("1238", "Reardon Kreamer", "Finance", "WA",6912,22,646),
("1239", "Charlie Yessenia", "Finance", "AK",7347,45,642),
("1240", "Toussaint Baros", "HR", "AK",5349,26,1035),
("1241", "Deandre Marvis", "Marketing", "NY",8778,31,1712),
("1242", "Mullan Barringer", "Purchasing", "CA",6631,21,782),
("1243", "Margret Marvis", "Purchasing", "AK",2659,42,842),
("1244", "Trena Janey", "Marketing", "LA",3936,40,1246),
("1245", "Marvis Drema", "HR", "CA",2550,23,503),
("1246", "Frisina Janey", "Finance", "WA",1547,45,820),
("1247", "Rudolph Georgeanna", "Sales", "AK",6702,36,689),
("1248", "Tamra Dedman", "HR", "AK",5589,33,1766),
("1249", "Gilma Janine", "Accounts", "NY",2955,23,1645),
("1250", "Richter Kall", "HR", "LA",7296,28,1155),
("1251", "Imai Shandra", "Finance", "LA",3661,46,880),
("1252", "Leif Marvis", "Purchasing", "LA",9200,20,1260),
("1253", "Kaczorowski Mayeda", "Accounts", "CA",3826,27,986),
("1254", "Imai Casimira", "Accounts", "WA",9846,34,1087),
("1255", "Phylicia Margret", "Purchasing", "CA",1637,32,1895),
("1256", "Marvis Megan", "Sales", "CA",1313,32,620),
("1257", "Recalde Locust", "Finance", "WA",7507,43,726),
("1258", "Nitz Ilana", "HR", "WA",6511,28,944),
("1259", "Gallman Nakano", "Accounts", "AK",1060,42,1663),
("1260", "Locust Tyree", "Sales", "WA",7334,35,1208),
("1261", "Suzanne Zollner", "Marketing", "WA",9008,36,854),
("1262", "Nakano Amber", "Marketing", "AK",3688,27,789),
("1263", "Georgeanna Reighard", "Marketing", "CA",9810,30,1205),
("1264", "Kaczorowski Amber", "HR", "AK",9478,30,674),
("1265", "Megan Leif", "HR", "AK",2534,44,853),
("1266", "Leonel Karie", "Marketing", "WA",3272,45,1785),
("1267", "Larry Villela", "Sales", "CA",8332,30,1518),
("1268", "Zollner Mckey", "HR", "LA",4807,21,1227),
("1269", "Nitz Mayeda", "HR", "CA",1670,26,1976),
("1270", "Barringer Hallie", "Purchasing", "CA",1934,27,1650),
("1271", "Vankirk Larry", "Accounts", "NY",8962,22,1229),
("1272", "Lemaster Fender", "Sales", "WA",2405,50,732),
("1273", "Karie Katlyn", "Marketing", "AK",5364,43,1481),
("1274", "Sifford Margret", "Purchasing", "LA",1725,34,958),
("1275", "Coogan Benz", "Marketing", "WA",1992,24,1986),
("1276", "Rudolph Zollner", "Sales", "LA",9702,41,1224),
("1277", "Toussaint Shandra", "Marketing", "LA",7712,31,1914),
("1278", "Melissia Jaclyn", "Purchasing", "AK",6810,43,872),
("1279", "Yessenia Dynes", "Marketing", "CA",9647,39,1148),
("1280", "Locust Dedman", "Finance", "WA",9294,32,505),
("1281", "Jaclyn Juliana", "Accounts", "WA",8212,40,1893),
("1282", "Recalde Zollner", "HR", "CA",8860,50,890),
("1283", "Grigg Rocha", "Sales", "LA",3368,20,1532),
("1284", "Zollner Juliana", "Marketing", "AK",6552,45,1766),
("1285", "Louann Jere", "Marketing", "LA",4753,30,1035),
("1286", "Kohn Vankirk", "Finance", "NY",5754,39,1229),
("1287", "Margret Ilana", "Accounts", "LA",9333,28,1663),
("1288", "Mayeda Katlyn", "Purchasing", "NY",1949,27,1827),
("1289", "Vivan Janey", "HR", "WA",7514,44,1454),
("1290", "Nitz Kall", "HR", "NY",9893,28,606),
("1291", "Antonio Gilma", "Sales", "AK",8110,27,735),
("1292", "Luisa Casimira", "Sales", "LA",6603,36,1672),
("1293", "Antonina Ullery", "Purchasing", "CA",1787,50,919),
("1294", "Soules Imai", "Sales", "CA",2653,33,1925),
("1295", "Coogan Suzanne", "Purchasing", "LA",2655,25,573),
("1296", "Lemaster Nena", "Purchasing", "NY",1186,31,1617),
("1297", "Tiffani Casimira", "Marketing", "LA",3344,41,1463),
("1298", "Mullan Norene", "Purchasing", "AK",3396,34,768),
("1299", "Nitz Nakano", "Accounts", "AK",4340,26,552),
("1300", "Suzanne Vankirk", "HR", "AK",1516,34,1519),
("1301", "Melissia Katlyn", "Finance", "NY",5731,26,525),
("1302", "Byrge Ullery", "Purchasing", "AK",6698,41,1152),
("1303", "Richter Escoto", "Finance", "AK",2021,44,671),
("1304", "Herder Gallman", "HR", "CA",8589,46,1086),
("1305", "Georgeanna Reardon", "Sales", "LA",6440,40,1705),
("1306", "Figueras Yessenia", "Marketing", "WA",1093,35,599),
("1307", "Casimira Leif", "HR", "CA",5849,45,1663),
("1308", "Frisina Frisina", "Marketing", "AK",8308,37,1806),
("1309", "Clune Recalde", "Sales", "CA",2648,33,1952),
("1310", "Deandre Lisabeth", "Sales", "CA",2262,45,1917),
("1311", "Tamra Nitz", "Sales", "NY",5853,43,1991),
("1312", "Leif Reighard", "Accounts", "NY",3774,23,1905),
("1313", "Ilana Bergren", "Marketing", "LA",6275,20,1554),
("1314", "Lisabeth Katlyn", "Purchasing", "CA",6320,38,1142),
("1315", "Kaczorowski Nitz", "Accounts", "LA",2603,36,1977),
("1316", "Nena Mcmillion", "Purchasing", "WA",9655,35,1747),
("1317", "Mullan Yessenia", "Purchasing", "WA",6023,42,1449),
("1318", "Luisa Rudolph", "HR", "NY",6794,48,1642),
("1319", "Reighard Shandra", "Sales", "CA",9359,27,1199),
("1320", "Escoto Recalde", "Marketing", "AK",5181,24,1360),
("1321", "Janey Laub", "HR", "LA",3422,28,1660),
("1322", "Charlie Fender", "Finance", "CA",9540,45,1639),
("1323", "Gilma Fender", "HR", "CA",1829,50,880),
("1324", "Clemencia Karie", "Sales", "CA",4673,26,1410),
("1325", "Bergren Barringer", "HR", "AK",8277,46,1277),
("1326", "Harrison Laub", "Marketing", "NY",5635,28,1452),
("1327", "Trena Phylicia", "Finance", "AK",4857,45,1527),
("1328", "Dynes Exie", "Marketing", "NY",8793,20,1653),
("1329", "Kohn Janine", "Purchasing", "AK",8906,31,1798),
("1330", "Casimira Kall", "Marketing", "WA",4109,24,1496),
("1331", "Hanh Coogan", "Marketing", "AK",8922,31,1311),
("1332", "Cobian Trena", "HR", "AK",6359,29,1140),
("1333", "Larry Shandra", "HR", "NY",6701,23,961),
("1334", "Trena Lemaster", "Finance", "LA",6283,50,831),
("1335", "Deandre Melissia", "Finance", "NY",8898,32,513),
("1336", "Layla Marvis", "HR", "NY",6196,50,1768),
("1337", "Vivan Ilana", "Accounts", "NY",4025,29,1920),
("1338", "Kall Mckey", "Purchasing", "AK",9514,38,1123),
("1339", "Jacquelyne Tiffani", "Accounts", "CA",1449,27,1654),
("1340", "Nakano Benz", "Marketing", "AK",3367,49,1221),
("1341", "Mullan Benz", "HR", "WA",6126,21,1685),
("1342", "Phylicia Antonina", "Finance", "NY",8626,30,1857),
("1343", "Melvina Trena", "Accounts", "WA",9592,50,1512),
("1344", "Durio Luisa", "Purchasing", "AK",1472,42,1715),
("1345", "Stanford Drema", "HR", "CA",5402,34,946),
("1346", "Debroah Tiffani", "Accounts", "AK",9357,46,573),
("1347", "Escoto Tyree", "Sales", "CA",7995,39,1731),
("1348", "Charlie Rocha", "HR", "AK",1874,25,791),
("1349", "Mayeda Villela", "Marketing", "AK",4237,27,1587),
("1350", "Vankirk Stanford", "Finance", "AK",2767,35,589),
("1351", "Escoto Rocha", "HR", "LA",8970,26,1628),
("1352", "Antonio Baros", "Accounts", "LA",4627,39,1583),
("1353", "Vivan Leif", "Marketing", "CA",1721,35,1949),
("1354", "Kreamer Kaczorowski", "HR", "CA",9857,49,524),
("1355", "Jacquelyne Melissia", "Marketing", "NY",7414,43,566),
("1356", "Sifford Antonina", "Purchasing", "CA",2357,46,1260),
("1357", "Byrge Benz", "Sales", "AK",6823,44,1932),
("1358", "Bergren Janine", "HR", "WA",6051,45,505),
("1359", "Louann Lonergan", "Marketing", "CA",3330,20,739),
("1360", "Amber Locust", "Purchasing", "LA",1922,50,1406),
("1361", "Fender Tyree", "Purchasing", "AK",5227,35,1400),
("1362", "Juliana Herder", "Accounts", "LA",1504,22,1994),
("1363", "Tenenbaum Imai", "Marketing", "NY",9658,33,531),
("1364", "Hallie Tenenbaum", "Marketing", "WA",1967,36,1379),
("1365", "Vivan Drema", "Marketing", "NY",8475,24,1028),
("1366", "Byrge Figueras", "Marketing", "WA",8493,39,628),
("1367", "Grigg Locust", "Marketing", "WA",3733,20,709),
("1368", "Kaczorowski Villela", "Marketing", "WA",4254,21,1616),
("1369", "Durio Jere", "Accounts", "LA",5409,27,1783),
("1370", "Frisina Lisabeth", "Accounts", "CA",5377,46,971),
("1371", "Lisabeth Hanh", "HR", "CA",3346,44,534),
("1372", "Benz Villela", "HR", "AK",8511,29,945),
("1373", "Casimira Mayeda", "Marketing", "WA",3253,38,1502),
("1374", "Melissia Dynes", "Purchasing", "AK",7833,30,1800),
("1375", "Tiffani Nakano", "HR", "NY",3378,33,1190),
("1376", "Antonio Tenenbaum", "HR", "WA",3036,28,1490),
("1377", "Ullery Kaczorowski", "Sales", "LA",8929,50,1554),
("1378", "Exie Frisina", "Marketing", "WA",1646,26,712),
("1379", "Byrge Lisabeth", "Accounts", "AK",5614,35,774),
("1380", "Jacquelyne Nakano", "Finance", "WA",7702,25,697),
("1381", "Luisa Clune", "Finance", "LA",3099,30,721),
("1382", "Imai Dynes", "Accounts", "AK",3219,22,1579),
("1383", "Villela Byrge", "Accounts", "CA",4627,29,1805),
("1384", "Juliana Grigg", "Marketing", "LA",6164,37,1612),
("1385", "Norene Charlie", "Purchasing", "AK",8908,44,593),
("1386", "Shandra Bergren", "HR", "NY",7646,27,1099),
("1387", "Melvina Richter", "Marketing", "WA",3877,34,1774),
("1388", "Harrison Baros", "Marketing", "AK",9640,46,532),
("1389", "Villela Amber", "Marketing", "WA",5522,21,1807),
("1390", "Clemencia Kensinger", "Accounts", "AK",6184,45,812),
("1391", "Leif Grigg", "Finance", "WA",4501,35,562),
("1392", "Lisabeth Baros", "Finance", "CA",6156,33,1713),
("1393", "Durio Melissia", "Finance", "CA",5506,31,1634),
("1394", "Sifford Layla", "Finance", "CA",3641,47,1707),
("1395", "Clemencia Nena", "Finance", "CA",4512,22,958),
("1396", "Nakano Nakano", "Finance", "LA",4369,27,1571),
("1397", "Rudolph Casimira", "HR", "WA",2532,41,1994),
("1398", "Jere Ellingsworth", "HR", "LA",8214,41,698),
("1399", "Leif Villela", "Accounts", "WA",6824,43,879),
("1400", "Bergren Clemencia", "Purchasing", "LA",5321,47,1169),
("1401", "Reardon Georgeanna", "HR", "NY",7793,45,748),
("1402", "Kreamer Debroah", "Purchasing", "WA",2195,35,1735),
("1403", "Larry Reardon", "HR", "NY",9004,48,716),
("1404", "Jere Frisina", "HR", "WA",9287,40,731),
("1405", "Grigg Ilana", "HR", "CA",4937,32,983),
("1406", "Georgeanna Lemaster", "Purchasing", "LA",8239,47,1405),
("1407", "Kaczorowski Marvis", "Marketing", "WA",1951,21,535),
("1408", "Dionne Durio", "HR", "LA",9624,34,1850),
("1409", "Mullan Gilma", "HR", "LA",4276,47,1158),
("1410", "Locust Mckey", "Accounts", "NY",3389,27,1471),
("1411", "Kaczorowski Debroah", "Marketing", "CA",8499,42,1826),
("1412", "Mckey Kreamer", "Purchasing", "LA",5413,32,684),
("1413", "Hallie Hanh", "Finance", "LA",2973,36,771),
("1414", "Durio Janey", "Finance", "NY",2992,46,1733),
("1415", "Nakano Larry", "Purchasing", "WA",1178,47,1545),
("1416", "Jere Cobian", "HR", "CA",5001,26,1463),
("1417", "Jacquelyne Layla", "Marketing", "CA",7497,37,842),
("1418", "Juliana Kreamer", "Finance", "NY",1006,45,651),
("1419", "Yessenia Antonina", "Marketing", "LA",2421,46,1514),
("1420", "Gallman Kohn", "HR", "AK",2395,30,712),
("1421", "Trena Vivan", "Sales", "LA",1152,24,689),
("1422", "Escoto Megan", "Accounts", "AK",4728,47,655),
("1423", "Dynes Clemencia", "Accounts", "CA",7982,23,864),
("1424", "Janine Hanh", "Accounts", "LA",5824,23,1370),
("1425", "Laub Marvis", "Sales", "NY",8747,46,1322),
("1426", "Leif Durio", "HR", "WA",7895,41,1585),
("1427", "Casimira Reardon", "Marketing", "WA",6794,25,1059),
("1428", "Ilana Ruzicka", "Sales", "LA",7714,45,1563),
("1429", "Recalde Tamra", "Sales", "NY",1402,25,1462),
("1430", "Gilma Marvis", "Purchasing", "LA",9138,34,1657),
("1431", "Escoto Luisa", "Sales", "LA",3656,25,1188),
("1432", "Janine Dynes", "Accounts", "NY",2270,25,656),
("1433", "Reighard Kensinger", "Purchasing", "WA",5248,49,1517),
("1434", "Rocha Leif", "Sales", "WA",4465,37,1737),
("1435", "Benz Antonio", "Marketing", "AK",5416,25,1058),
("1436", "Ilana Grigg", "Accounts", "AK",2412,35,754),
("1437", "Dynes Phylicia", "Marketing", "AK",3444,30,1668),
("1438", "Leonel Kohn", "Finance", "AK",3855,27,1053),
("1439", "Megan Lisabeth", "HR", "WA",5343,24,684),
("1440", "Clemencia Coogan", "Accounts", "CA",6722,27,748),
("1441", "Shandra Frisina", "Sales", "AK",6010,46,508),
("1442", "Ullery Rudolph", "Sales", "AK",6490,48,1085),
("1443", "Rudolph Dionne", "HR", "LA",9413,23,1559),
("1444", "Benz Ilana", "HR", "LA",9101,48,518),
("1445", "Leonel Coogan", "Marketing", "WA",9152,34,741),
("1446", "Dionne Recalde", "Purchasing", "CA",3164,25,965),
("1447", "Ullery Tyree", "HR", "WA",6157,42,1557),
("1448", "Gilma Janine", "HR", "CA",9097,31,746),
("1449", "Amber Tyree", "HR", "LA",1429,47,1177),
("1450", "Amber Byrge", "Finance", "CA",8036,29,835),
("1451", "Margret Zollner", "HR", "WA",2168,36,1509),
("1452", "Melvina Zollner", "Marketing", "NY",5345,48,1371),
("1453", "Byrge Hallie", "HR", "WA",8457,41,1979),
("1454", "Tamra Melissia", "Accounts", "CA",8544,32,1734),
("1455", "Juliana Charlie", "HR", "LA",5738,27,622),
("1456", "Margret Rudolph", "Sales", "AK",2375,48,604),
("1457", "Rocha Sifford", "Marketing", "NY",9140,45,1051),
("1458", "Harrison Lisabeth", "Marketing", "WA",4375,22,1000),
("1459", "Rudolph Amber", "HR", "LA",8579,41,1499),
("1460", "Imai Stanford", "Finance", "WA",9636,29,1612),
("1461", "Norene Luisa", "Sales", "AK",2471,47,1215),
("1462", "Reardon Juliana", "Finance", "WA",5881,48,1306),
("1463", "Antonina Ruzicka", "Sales", "LA",8269,43,537),
("1464", "Locust Exie", "Finance", "WA",3791,25,723),
("1465", "Janine Tyree", "Sales", "AK",7589,37,1251),
("1466", "Byrge Kaczorowski", "Purchasing", "CA",3612,28,1050),
("1467", "Karie Leonel", "Marketing", "CA",3415,35,1173),
("1468", "Karie Antonio", "Purchasing", "LA",1876,47,1949),
("1469", "Vivan Antonio", "Marketing", "WA",5173,35,533),
("1470", "Kreamer Ellingsworth", "Sales", "CA",6729,34,1646),
("1471", "Melvina Nakano", "Accounts", "CA",2771,32,530),
("1472", "Melissia Drema", "Accounts", "NY",3785,25,770),
("1473", "Mayeda Villela", "Marketing", "CA",5420,20,813),
("1474", "Barringer Baros", "Purchasing", "LA",7200,39,974),
("1475", "Harrison Nitz", "HR", "WA",9982,43,1362),
("1476", "Escoto Gallman", "Purchasing", "LA",5416,40,1790),
("1477", "Harrison Ilana", "HR", "AK",8111,48,1830),
("1478", "Trena Vivan", "Finance", "CA",3221,34,1860),
("1479", "Larry Antonio", "Finance", "CA",5850,48,1382),
("1480", "Recalde Hallie", "Purchasing", "LA",3107,31,1265),
("1481", "Yukiko Mckey", "HR", "AK",4553,33,1901),
("1482", "Ullery Dionne", "Purchasing", "WA",3701,31,1105),
("1483", "Ullery Nitz", "HR", "NY",3003,40,1638),
("1484", "Katlyn Jere", "Accounts", "LA",4803,46,1873),
("1485", "Suzanne Vankirk", "Accounts", "WA",3463,40,1353),
("1486", "Gallman Lonergan", "Sales", "CA",7748,44,1351),
("1487", "Kohn Kreamer", "Sales", "CA",8194,38,1894),
("1488", "Benz Ilana", "Finance", "WA",8251,36,579),
("1489", "Janine Melvina", "Purchasing", "LA",3116,33,1167),
("1490", "Kreamer Figueras", "Marketing", "AK",5916,34,1225),
("1491", "Rocha Harrison", "Purchasing", "WA",7308,46,1521),
("1492", "Mayeda Margret", "Accounts", "AK",2735,30,1584),
("1493", "Dionne Grigg", "Accounts", "AK",1825,39,822),
("1494", "Kohn Lisabeth", "Sales", "AK",6707,24,783),
("1495", "Harrison Lonergan", "Finance", "CA",2235,37,1609),
("1496", "Vankirk Kaczorowski", "Sales", "WA",7672,42,1123),
("1497", "Leonel Figueras", "Accounts", "LA",3610,35,1810),
("1498", "Lonergan Imai", "Accounts", "CA",4771,22,1048),
("1499", "Leif Dynes", "HR", "WA",6965,25,518),
("1500", "Lemaster Exie", "Marketing", "LA",3262,34,975),
("1501", "Stanford Katlyn", "Marketing", "WA",5200,34,834),
("1502", "Antonio Jaclyn", "Purchasing", "WA",7002,42,1040),
("1503", "Stanford Richter", "Accounts", "WA",4909,33,1256),
("1504", "Georgeanna Janey", "Marketing", "CA",5078,25,1009),
("1505", "Nitz Suzanne", "Finance", "LA",2361,30,1093),
("1506", "Deandre Clune", "Accounts", "LA",6801,23,1665),
("1507", "Rocha Ilana", "Finance", "AK",4671,33,1796),
("1508", "Vivan Fender", "HR", "CA",7699,38,1843),
("1509", "Ellingsworth Nitz", "Finance", "NY",7234,45,1004),
("1510", "Nitz Cobian", "Marketing", "AK",9222,50,1152),
("1511", "Kreamer Juliana", "Sales", "NY",3510,43,1017),
("1512", "Vankirk Megan", "HR", "LA",6365,49,1554),
("1513", "Jere Dedman", "Accounts", "LA",5715,32,1914),
("1514", "Clemencia Nakano", "Finance", "AK",5563,31,1787),
("1515", "Zollner Gilma", "Finance", "CA",8924,50,1161),
("1516", "Durio Melissia", "Finance", "WA",3423,39,1275),
("1517", "Gallman Clemencia", "Finance", "AK",9532,36,1592),
("1518", "Louann Deandre", "Finance", "CA",9546,24,548),
("1519", "Melissia Casimira", "Sales", "LA",6300,47,1131),
("1520", "Karie Mcmillion", "HR", "WA",6466,29,726),
("1521", "Laub Norene", "Sales", "AK",5645,40,1887),
("1522", "Jaclyn Jaclyn", "HR", "AK",7505,49,1081),
("1523", "Richter Coogan", "Purchasing", "WA",9640,38,1090),
("1524", "Kreamer Drema", "Purchasing", "LA",9329,45,1132),
("1525", "Kreamer Mayeda", "Accounts", "NY",3669,24,1862),
("1526", "Margret Katlyn", "Finance", "CA",1636,45,1639),
("1527", "Ruzicka Vivan", "Accounts", "AK",3374,40,647),
("1528", "Mullan Shandra", "Sales", "AK",4604,43,1998),
("1529", "Dynes Coogan", "Finance", "NY",3102,28,532),
("1530", "Ilana Katlyn", "Sales", "CA",7959,46,1138),
("1531", "Cobian Laub", "Marketing", "NY",2741,30,939),
("1532", "Harrison Barringer", "HR", "WA",7874,50,1184),
("1533", "Hanh Lonergan", "Finance", "CA",8393,34,704),
("1534", "Figueras Kohn", "Purchasing", "CA",9287,24,1234),
("1535", "Norene Richter", "Purchasing", "CA",3812,23,615),
("1536", "Soules Stanford", "HR", "AK",3616,50,1703),
("1537", "Karie Tiffani", "Sales", "CA",9579,32,1012),
("1538", "Nitz Tamra", "Purchasing", "AK",4512,21,556),
("1539", "Vivan Benz", "Sales", "AK",2725,48,1549),
("1540", "Mullan Bergren", "Sales", "LA",5889,24,740),
("1541", "Dedman Kall", "Sales", "NY",3755,27,1984),
("1542", "Yukiko Norene", "HR", "LA",9696,26,1226),
("1543", "Trena Stanford", "Purchasing", "LA",6800,27,1126),
("1544", "Shandra Stanford", "Finance", "LA",1880,36,728),
("1545", "Toussaint Zollner", "Finance", "AK",9173,20,765),
("1546", "Ilana Ilana", "HR", "LA",4321,35,818),
("1547", "Herder Larry", "Purchasing", "LA",3582,25,567),
("1548", "Exie Leonel", "Marketing", "AK",4930,48,1761),
("1549", "Reighard Kaczorowski", "Sales", "NY",2129,24,1392),
("1550", "Byrge Larry", "Marketing", "AK",1167,34,1682),
("1551", "Herder Gallman", "Purchasing", "NY",4525,26,1701),
("1552", "Laub Karie", "Sales", "AK",7882,42,1122),
("1553", "Rocha Trena", "Accounts", "LA",4457,34,1572),
("1554", "Imai Hanh", "Purchasing", "LA",9171,38,1636),
("1555", "Antonio Locust", "Finance", "CA",4770,23,999),
("1556", "Mullan Ellingsworth", "Marketing", "WA",1496,29,1614),
("1557", "Ullery Imai", "Sales", "WA",3044,39,1960),
("1558", "Luisa Clune", "Purchasing", "WA",2101,39,1063),
("1559", "Tamra Bergren", "Purchasing", "WA",2677,43,1248),
("1560", "Kall Lisabeth", "Purchasing", "LA",4967,44,696),
("1561", "Benz Frisina", "Marketing", "AK",3414,28,1735),
("1562", "Karie Hallie", "Marketing", "WA",6888,41,916),
("1563", "Karie Kall", "Purchasing", "LA",4911,31,1034),
("1564", "Layla Layla", "Finance", "LA",1595,40,783),
("1565", "Mayeda Marvis", "Finance", "LA",7123,27,533),
("1566", "Georgeanna Janey", "HR", "WA",7393,49,1813),
("1567", "Cobian Harrison", "Purchasing", "LA",9267,36,1036),
("1568", "Soules Laub", "Accounts", "LA",4658,31,1341),
("1569", "Rocha Margret", "Sales", "CA",1164,49,674),
("1570", "Larry Gilma", "HR", "AK",5019,26,1742),
("1571", "Reighard Antonio", "Marketing", "NY",3004,32,680),
("1572", "Mullan Villela", "Sales", "LA",5968,45,1479),
("1573", "Ilana Charlie", "HR", "LA",1654,38,1317),
("1574", "Hallie Figueras", "Marketing", "CA",7532,46,1655),
("1575", "Kaczorowski Yukiko", "HR", "NY",5082,50,1727),
("1576", "Karie Jaclyn", "Sales", "LA",2611,47,1026),
("1577", "Dynes Reardon", "Sales", "LA",5311,47,1865),
("1578", "Lisabeth Rocha", "Sales", "LA",7954,48,1514),
("1579", "Juliana Bergren", "Sales", "CA",4407,37,1284),
("1580", "Mayeda Ullery", "Accounts", "NY",7411,42,1067),
("1581", "Vankirk Kaczorowski", "Accounts", "CA",5266,21,1503),
("1582", "Hanh Hanh", "Accounts", "NY",5399,43,1821),
("1583", "Villela Casimira", "HR", "LA",2422,27,1537),
("1584", "Fender Bergren", "Purchasing", "NY",5180,22,1312),
("1585", "Karie Yukiko", "Finance", "LA",3405,29,610),
("1586", "Juliana Escoto", "Finance", "LA",8182,29,721),
("1587", "Herder Tyree", "HR", "WA",3490,45,1062),
("1588", "Melissia Locust", "Purchasing", "CA",3108,30,1859),
("1589", "Tenenbaum Gilma", "Sales", "LA",8439,39,1676),
("1590", "Norene Janey", "Marketing", "AK",7101,22,1870),
("1591", "Jacquelyne Zollner", "Finance", "WA",4135,28,1241),
("1592", "Amber Georgeanna", "HR", "WA",9946,34,1812),
("1593", "Escoto Janey", "Accounts", "LA",7736,23,764),
("1594", "Kensinger Jere", "Accounts", "NY",9114,45,1263),
("1595", "Gilma Mullan", "Accounts", "NY",8688,48,530),
("1596", "Karie Norene", "Sales", "CA",4228,27,1928),
("1597", "Kaczorowski Janey", "Sales", "AK",3949,45,1774),
("1598", "Janey Leonel", "Finance", "WA",1651,34,743),
("1599", "Herder Dedman", "Accounts", "CA",7934,21,1081),
("1600", "Margret Tiffani", "Marketing", "CA",5695,37,885),
("1601", "Louann Jaclyn", "Accounts", "AK",5751,35,922),
("1602", "Tenenbaum Coogan", "Accounts", "WA",9442,30,1577),
("1603", "Imai Kall", "Finance", "AK",8565,35,1086),
("1604", "Frisina Ruzicka", "Sales", "AK",5591,27,1882),
("1605", "Imai Janine", "Purchasing", "NY",4380,31,1830),
("1606", "Escoto Casimira", "HR", "WA",6173,41,1788),
("1607", "Janey Layla", "Sales", "AK",4795,24,1153),
("1608", "Gilma Casimira", "Sales", "AK",4602,26,1365),
("1609", "Zollner Yukiko", "Marketing", "AK",5535,48,937),
("1610", "Soules Luisa", "HR", "NY",5691,48,797),
("1611", "Georgeanna Vivan", "Purchasing", "CA",2588,48,594),
("1612", "Mullan Yukiko", "Marketing", "NY",7758,39,860),
("1613", "Hallie Jere", "Marketing", "AK",3936,27,1076),
("1614", "Suzanne Kohn", "Purchasing", "CA",2576,41,906),
("1615", "Richter Coogan", "Purchasing", "LA",4376,24,1045),
("1616", "Kall Trena", "Finance", "CA",3084,47,1871),
("1617", "Dedman Ilana", "Sales", "CA",1712,49,743),
("1618", "Nakano Kreamer", "HR", "WA",3043,35,953),
("1619", "Antonina Recalde", "Marketing", "WA",2304,29,822),
("1620", "Drema Drema", "Accounts", "AK",2455,20,1360),
("1621", "Cobian Soules", "Marketing", "AK",3933,23,819),
("1622", "Lonergan Deandre", "Accounts", "WA",4593,42,1520),
("1623", "Byrge Tiffani", "Purchasing", "WA",9375,23,574),
("1624", "Tamra Melissia", "Purchasing", "WA",1528,25,1895),
("1625", "Antonio Hallie", "HR", "WA",2564,45,1076),
("1626", "Ullery Kaczorowski", "Sales", "WA",9015,46,938),
("1627", "Lemaster Sifford", "Marketing", "CA",2853,20,1084),
("1628", "Villela Reardon", "Accounts", "LA",8650,20,1546),
("1629", "Leonel Megan", "Sales", "LA",9592,28,1342),
("1630", "Imai Debroah", "Marketing", "WA",5839,20,1034),
("1631", "Gilma Fender", "HR", "WA",8806,41,1904),
("1632", "Layla Drema", "Sales", "CA",8898,30,980),
("1633", "Karie Bergren", "Finance", "WA",1337,26,1907),
("1634", "Barringer Figueras", "Purchasing", "NY",4228,42,833),
("1635", "Locust Imai", "HR", "NY",8560,33,1866),
("1636", "Grigg Recalde", "Accounts", "CA",2262,47,730),
("1637", "Janey Jaclyn", "Sales", "AK",3399,27,691),
("1638", "Casimira Juliana", "Accounts", "AK",2967,24,974),
("1639", "Melvina Stanford", "Purchasing", "CA",2353,30,1860),
("1640", "Baros Dedman", "HR", "CA",8470,31,1913),
("1641", "Jacquelyne Escoto", "Sales", "WA",7763,46,727),
("1642", "Bergren Yessenia", "Marketing", "WA",5644,23,1944),
("1643", "Herder Yessenia", "HR", "WA",2298,46,853),
("1644", "Rocha Drema", "Finance", "NY",3662,32,586),
("1645", "Janine Zollner", "Sales", "CA",7685,44,1215),
("1646", "Nitz Tyree", "Marketing", "AK",3943,48,809),
("1647", "Drema Jaclyn", "Finance", "LA",5232,46,872),
("1648", "Durio Imai", "HR", "LA",6261,33,860),
("1649", "Recalde Kall", "HR", "NY",5407,21,1894),
("1650", "Lonergan Bergren", "Sales", "CA",9643,34,551),
("1651", "Shandra Marvis", "Marketing", "CA",7222,40,1075),
("1652", "Coogan Grigg", "Sales", "NY",8907,41,727),
("1653", "Debroah Herder", "Sales", "LA",4018,47,1853),
("1654", "Louann Ellingsworth", "Marketing", "WA",6705,22,1593),
("1655", "Norene Amber", "Finance", "AK",9261,23,1885),
("1656", "Tenenbaum Luisa", "HR", "WA",5220,46,942),
("1657", "Nakano Durio", "Purchasing", "NY",6671,44,1253),
("1658", "Yukiko Dedman", "Sales", "AK",4340,42,1046),
("1659", "Byrge Antonina", "Sales", "AK",4085,32,1565),
("1660", "Melissia Jere", "Finance", "NY",9201,21,1533),
("1661", "Lonergan Jere", "Purchasing", "CA",7513,44,725),
("1662", "Leonel Laub", "Sales", "NY",4359,28,1173),
("1663", "Sifford Trena", "Accounts", "WA",3378,39,546),
("1664", "Imai Karie", "Finance", "LA",3033,27,1977),
("1665", "Imai Cobian", "Purchasing", "CA",9297,48,1092),
("1666", "Janey Tenenbaum", "HR", "NY",3409,29,1370),
("1667", "Melissia Antonio", "HR", "AK",6471,34,782),
("1668", "Antonina Louann", "Accounts", "AK",9580,44,1650),
("1669", "Benz Baros", "Purchasing", "LA",2217,29,1809),
("1670", "Rocha Coogan", "Accounts", "AK",1210,46,1753),
("1671", "Gilma Casimira", "HR", "LA",6552,33,1803),
("1672", "Casimira Stanford", "Accounts", "LA",1268,24,1828),
("1673", "Debroah Antonina", "HR", "WA",3248,39,1537),
("1674", "Jere Janey", "HR", "AK",8859,33,1693),
("1675", "Jaclyn Antonio", "Purchasing", "AK",2374,26,951),
("1676", "Frisina Cobian", "Sales", "LA",5324,30,1631),
("1677", "Rocha Rudolph", "Purchasing", "LA",7321,28,1118),
("1678", "Jere Tiffani", "Marketing", "WA",3734,34,1218),
("1679", "Kaczorowski Hallie", "HR", "AK",9137,49,1014),
("1680", "Georgeanna Marvis", "Marketing", "LA",4105,26,1120),
("1681", "Megan Janine", "Sales", "WA",5788,26,1469),
("1682", "Drema Nitz", "Finance", "WA",9167,40,1790),
("1683", "Lemaster Nena", "Marketing", "CA",1217,31,1761),
("1684", "Laub Dionne", "Sales", "AK",9639,32,727),
("1685", "Lonergan Deandre", "Accounts", "NY",8045,47,1606),
("1686", "Lonergan Kall", "HR", "LA",1360,38,646),
("1687", "Zollner Antonio", "Marketing", "LA",5857,29,520),
("1688", "Debroah Norene", "Sales", "NY",3809,40,655),
("1689", "Recalde Drema", "Purchasing", "CA",8344,38,683),
("1690", "Norene Kall", "HR", "CA",9662,27,1291),
("1691", "Dedman Tiffani", "HR", "WA",9093,45,1315),
("1692", "Coogan Hallie", "HR", "LA",4828,44,630),
("1693", "Tamra Soules", "Sales", "AK",2562,38,1875),
("1694", "Ullery Lemaster", "Marketing", "NY",3675,46,1998),
("1695", "Suzanne Megan", "Marketing", "AK",2204,27,1020),
("1696", "Casimira Locust", "Accounts", "WA",8024,33,1534),
("1697", "Fender Villela", "Finance", "CA",3056,25,845),
("1698", "Casimira Melvina", "Purchasing", "LA",3018,28,1012),
("1699", "Locust Tyree", "Purchasing", "WA",1416,43,1644),
("1700", "Sifford Barringer", "Accounts", "WA",6640,27,1619),
("1701", "Trena Melvina", "Marketing", "AK",5296,34,1776),
("1702", "Rudolph Juliana", "Marketing", "NY",7623,47,1166),
("1703", "Kall Dynes", "Purchasing", "LA",6643,36,614),
("1704", "Herder Laub", "Accounts", "NY",4749,38,733),
("1705", "Stanford Ruzicka", "Finance", "AK",4244,45,882),
("1706", "Melissia Kaczorowski", "Accounts", "NY",3663,22,1592),
("1707", "Frisina Dionne", "Marketing", "AK",7351,48,1239),
("1708", "Tamra Dynes", "Finance", "CA",1553,45,711),
("1709", "Megan Yessenia", "Sales", "WA",1820,45,1782),
("1710", "Benz Louann", "HR", "AK",4923,50,958),
("1711", "Leonel Rocha", "Marketing", "WA",4091,22,817),
("1712", "Janey Suzanne", "Marketing", "NY",1819,36,806),
("1713", "Yessenia Byrge", "HR", "NY",1118,38,1489),
("1714", "Ilana Laub", "Marketing", "WA",4519,38,1100),
("1715", "Lisabeth Yessenia", "Accounts", "LA",7417,48,907),
("1716", "Kaczorowski Charlie", "Finance", "CA",7902,35,1763),
("1717", "Leif Shandra", "Purchasing", "AK",7060,33,902),
("1718", "Amber Lisabeth", "Accounts", "LA",5048,20,724),
("1719", "Tenenbaum Phylicia", "Accounts", "NY",4179,21,1769),
("1720", "Locust Hanh", "Finance", "AK",1737,48,1243),
("1721", "Dionne Soules", "Sales", "NY",2697,22,1715),
("1722", "Harrison Casimira", "Finance", "CA",4052,41,1901),
("1723", "Recalde Marvis", "Purchasing", "NY",3272,38,1648),
("1724", "Shandra Lemaster", "Marketing", "LA",4329,34,1576),
("1725", "Melissia Imai", "Finance", "NY",2179,33,712),
("1726", "Yukiko Dedman", "Accounts", "LA",6304,43,1010),
("1727", "Exie Hanh", "Marketing", "CA",6842,47,563),
("1728", "Locust Drema", "Purchasing", "LA",1648,33,1573),
("1729", "Figueras Figueras", "HR", "NY",4963,50,884),
("1730", "Yessenia Karie", "HR", "WA",9893,28,635),
("1731", "Mayeda Lemaster", "HR", "LA",3710,40,758),
("1732", "Durio Jere", "Purchasing", "WA",3614,42,870),
("1733", "Melissia Leif", "Accounts", "CA",8701,44,958),
("1734", "Laub Dionne", "Accounts", "LA",8385,50,1870),
("1735", "Kensinger Dynes", "Purchasing", "AK",2112,20,1378),
("1736", "Dynes Kall", "Purchasing", "NY",1121,45,1735),
("1737", "Yukiko Kreamer", "Finance", "NY",7396,20,1332),
("1738", "Nena Kensinger", "Finance", "NY",8534,41,1610),
("1739", "Lemaster Amber", "Purchasing", "LA",9504,26,991),
("1740", "Melvina Margret", "Sales", "CA",9939,39,1077),
("1741", "Melissia Reighard", "Accounts", "WA",3537,45,922),
("1742", "Durio Phylicia", "Marketing", "CA",1262,31,1435),
("1743", "Lonergan Recalde", "Accounts", "CA",7045,34,839),
("1744", "Hanh Tyree", "HR", "CA",1093,47,635),
("1745", "Hallie Vivan", "Finance", "LA",4771,38,728),
("1746", "Coogan Zollner", "Sales", "LA",2988,45,1481),
("1747", "Charlie Debroah", "Marketing", "WA",4882,35,1299),
("1748", "Gallman Fender", "Sales", "CA",5314,30,1938),
("1749", "Zollner Tyree", "Marketing", "LA",5665,42,1489),
("1750", "Tamra Nitz", "Purchasing", "NY",4345,23,1255),
("1751", "Tamra Exie", "Purchasing", "WA",8644,35,774),
("1752", "Grigg Richter", "Marketing", "WA",3820,22,1379),
("1753", "Lisabeth Juliana", "Accounts", "NY",3852,20,569),
("1754", "Reighard Locust", "Accounts", "CA",1548,35,1753),
("1755", "Charlie Mcmillion", "HR", "NY",9283,38,984),
("1756", "Toussaint Clune", "Purchasing", "LA",4978,48,1318),
("1757", "Tenenbaum Leif", "Marketing", "CA",1981,50,909),
("1758", "Katlyn Jere", "Sales", "LA",8990,28,1085),
("1759", "Jacquelyne Soules", "Finance", "LA",1503,21,1398),
("1760", "Vankirk Grigg", "Accounts", "WA",9890,35,1762),
("1761", "Toussaint Grigg", "Purchasing", "LA",2558,22,1775),
("1762", "Amber Ullery", "Purchasing", "CA",9985,47,1408),
("1763", "Norene Nena", "Accounts", "AK",2793,44,752),
("1764", "Zollner Hallie", "Marketing", "LA",9776,31,1493),
("1765", "Tenenbaum Vivan", "HR", "WA",3801,29,1060),
("1766", "Trena Margret", "Marketing", "WA",9226,32,1180),
("1767", "Gilma Leonel", "Sales", "LA",3344,40,1641),
("1768", "Vivan Jacquelyne", "Finance", "WA",3669,28,1051),
("1769", "Drema Laub", "Accounts", "AK",4101,34,766),
("1770", "Baros Georgeanna", "Finance", "LA",5526,41,1799),
("1771", "Toussaint Gallman", "Sales", "WA",8387,32,1348),
("1772", "Frisina Charlie", "Marketing", "AK",3890,28,1807),
("1773", "Karie Recalde", "Sales", "NY",5482,42,1470),
("1774", "Antonina Phylicia", "HR", "AK",5184,22,1607),
("1775", "Clemencia Lisabeth", "Marketing", "NY",9178,48,788),
("1776", "Lonergan Juliana", "Purchasing", "WA",7327,33,795),
("1777", "Janey Cobian", "HR", "CA",1710,38,952),
("1778", "Shandra Coogan", "Accounts", "WA",2369,30,1592),
("1779", "Casimira Reighard", "Sales", "CA",2902,30,1432),
("1780", "Margret Reardon", "Finance", "NY",9677,47,567),
("1781", "Tyree Rudolph", "Marketing", "CA",4957,37,1715),
("1782", "Leonel Jere", "Accounts", "CA",5004,37,1445),
("1783", "Figueras Richter", "Marketing", "WA",6199,20,1603),
("1784", "Phylicia Margret", "Marketing", "AK",2740,38,1318),
("1785", "Tyree Vankirk", "Marketing", "NY",6825,39,1134),
("1786", "Fender Mayeda", "Finance", "WA",3540,39,1104),
("1787", "Antonina Yessenia", "Marketing", "WA",4180,34,1508),
("1788", "Gilma Janine", "Purchasing", "LA",8543,25,761),
("1789", "Jacquelyne Clemencia", "Accounts", "AK",2173,49,914),
("1790", "Lisabeth Larry", "Marketing", "WA",4949,31,1475),
("1791", "Tyree Jere", "Purchasing", "CA",8886,46,597),
("1792", "Soules Bergren", "HR", "LA",9453,37,911),
("1793", "Margret Imai", "Purchasing", "AK",4121,46,1396),
("1794", "Janey Barringer", "Marketing", "LA",1714,32,815),
("1795", "Dionne Fender", "HR", "WA",4724,22,1070),
("1796", "Nakano Lemaster", "Purchasing", "WA",8116,37,1496),
("1797", "Nitz Fender", "Purchasing", "AK",7330,43,1648),
("1798", "Mayeda Trena", "Purchasing", "AK",4511,28,1556),
("1799", "Yessenia Kall", "HR", "CA",6656,49,1350),
("1800", "Richter Imai", "HR", "WA",8106,50,1350),
("1801", "Juliana Recalde", "HR", "LA",8425,35,1850),
("1802", "Drema Harrison", "HR", "LA",2575,22,1217),
("1803", "Rudolph Nakano", "Sales", "NY",5467,27,1078),
("1804", "Norene Mayeda", "Finance", "CA",6499,41,936),
("1805", "Mckey Clune", "Accounts", "WA",9436,48,1795),
("1806", "Lemaster Dynes", "Accounts", "NY",5947,35,690),
("1807", "Lemaster Casimira", "Finance", "AK",8257,47,1420),
("1808", "Nakano Durio", "Purchasing", "LA",5060,39,1874),
("1809", "Yessenia Kreamer", "Purchasing", "NY",3041,36,648),
("1810", "Casimira Ullery", "HR", "CA",2467,49,584),
("1811", "Yessenia Antonio", "HR", "LA",9650,46,806),
("1812", "Norene Fender", "Marketing", "CA",4410,41,1241),
("1813", "Janey Nitz", "Sales", "AK",1945,25,1273),
("1814", "Kall Tamra", "Finance", "CA",6508,28,1858),
("1815", "Antonina Ilana", "Finance", "NY",2944,28,1718),
("1816", "Debroah Georgeanna", "Accounts", "CA",1806,29,1031),
("1817", "Frisina Ilana", "Accounts", "NY",2121,22,985),
("1818", "Exie Kreamer", "Marketing", "LA",5343,30,786),
("1819", "Jere Vankirk", "Accounts", "CA",6411,33,1797),
("1820", "Cobian Ilana", "Sales", "NY",4883,48,786),
("1821", "Vankirk Melissia", "Sales", "CA",2548,42,790),
("1822", "Lisabeth Luisa", "Marketing", "NY",1031,45,878),
("1823", "Recalde Ellingsworth", "Accounts", "NY",4872,38,1052),
("1824", "Melvina Dionne", "HR", "AK",8229,48,999),
("1825", "Margret Larry", "Accounts", "NY",9321,44,909),
("1826", "Kall Ellingsworth", "HR", "WA",2998,50,1759),
("1827", "Laub Antonina", "Sales", "LA",1117,31,1916),
("1828", "Clemencia Nakano", "Sales", "LA",8092,37,1219),
("1829", "Megan Fender", "Accounts", "WA",6741,47,1478),
("1830", "Yukiko Byrge", "HR", "AK",1500,43,1820),
("1831", "Karie Casimira", "Finance", "LA",5057,23,949),
("1832", "Katlyn Ruzicka", "Marketing", "LA",6558,32,911),
("1833", "Dionne Vivan", "Sales", "WA",6132,27,1434),
("1834", "Leif Yukiko", "Sales", "NY",3323,27,705),
("1835", "Tamra Larry", "Finance", "CA",6327,23,1681),
("1836", "Laub Lonergan", "Marketing", "WA",5446,37,676),
("1837", "Kall Lemaster", "Sales", "AK",9856,37,1365),
("1838", "Escoto Georgeanna", "Finance", "WA",9220,32,1899),
("1839", "Casimira Laub", "Finance", "AK",3779,47,1582),
("1840", "Kall Stanford", "Purchasing", "LA",9323,33,1781),
("1841", "Zollner Leonel", "Purchasing", "NY",4665,41,1977),
("1842", "Karie Fender", "Marketing", "LA",4286,26,1644),
("1843", "Lemaster Melvina", "Marketing", "AK",3983,34,1798),
("1844", "Reighard Exie", "HR", "WA",6011,48,510),
("1845", "Stanford Luisa", "Finance", "NY",8499,47,595),
("1846", "Rudolph Locust", "Accounts", "NY",7909,36,1731),
("1847", "Ellingsworth Harrison", "Purchasing", "CA",9764,22,1561),
("1848", "Laub Leif", "Marketing", "LA",2290,26,1836),
("1849", "Lemaster Melissia", "Purchasing", "CA",6235,42,1279),
("1850", "Nitz Ullery", "Accounts", "AK",8824,30,1743),
("1851", "Clune Juliana", "Accounts", "AK",1463,44,950),
("1852", "Amber Reighard", "Sales", "CA",9545,32,1336),
("1853", "Vivan Mckey", "HR", "NY",6101,44,1084),
("1854", "Kensinger Benz", "Finance", "NY",7739,28,611),
("1855", "Larry Megan", "Purchasing", "WA",2273,25,1438),
("1856", "Ullery Frisina", "Marketing", "AK",6899,38,941),
("1857", "Marvis Mcmillion", "Accounts", "NY",7346,29,1362),
("1858", "Jere Shandra", "Marketing", "WA",9209,47,800),
("1859", "Stanford Nakano", "Finance", "WA",5864,35,1212),
("1860", "Cobian Bergren", "Marketing", "AK",1707,25,1691),
("1861", "Frisina Phylicia", "HR", "NY",3314,26,1434),
("1862", "Harrison Ellingsworth", "Sales", "NY",1200,31,1120),
("1863", "Coogan Kensinger", "Purchasing", "NY",2612,22,1839),
("1864", "Soules Laub", "Accounts", "NY",1782,25,625),
("1865", "Laub Juliana", "Purchasing", "CA",7246,41,1070),
("1866", "Coogan Coogan", "Sales", "NY",4185,25,1378),
("1867", "Nakano Jaclyn", "Marketing", "AK",1579,42,515),
("1868", "Yessenia Kensinger", "Accounts", "CA",6026,39,1628),
("1869", "Ilana Nakano", "HR", "NY",9634,49,712),
("1870", "Melissia Locust", "HR", "AK",6759,49,730),
("1871", "Janine Yessenia", "Accounts", "NY",3996,26,1770),
("1872", "Gilma Bergren", "HR", "NY",6663,24,974),
("1873", "Fender Phylicia", "Finance", "AK",2321,28,600),
("1874", "Mayeda Kreamer", "HR", "LA",5850,21,1914),
("1875", "Nitz Georgeanna", "Purchasing", "AK",1504,44,740),
("1876", "Charlie Nena", "Purchasing", "NY",8248,35,1075),
("1877", "Luisa Georgeanna", "Accounts", "LA",5383,33,1137),
("1878", "Jere Nakano", "Finance", "WA",4302,45,1885),
("1879", "Ellingsworth Norene", "Sales", "AK",3940,41,1047),
("1880", "Melvina Rocha", "HR", "WA",8628,46,1973),
("1881", "Antonio Dynes", "Purchasing", "AK",2967,46,1618),
("1882", "Janine Toussaint", "HR", "WA",9848,30,1980),
("1883", "Hanh Cobian", "Marketing", "AK",9793,48,1410),
("1884", "Figueras Tenenbaum", "Sales", "WA",3273,22,1037),
("1885", "Fender Coogan", "Finance", "CA",3157,48,1512),
("1886", "Margret Larry", "Sales", "CA",5409,36,982),
("1887", "Mayeda Ruzicka", "Accounts", "NY",6896,39,1826),
("1888", "Marvis Louann", "Finance", "AK",7203,39,1341),
("1889", "Coogan Leonel", "Purchasing", "LA",3321,45,1941),
("1890", "Exie Dynes", "Purchasing", "NY",6936,29,1366),
("1891", "Nena Coogan", "Marketing", "NY",9240,42,1360),
("1892", "Lonergan Megan", "Sales", "WA",1103,38,1147),
("1893", "Reardon Ilana", "HR", "NY",4794,47,571),
("1894", "Dynes Laub", "HR", "WA",3729,24,768),
("1895", "Mckey Jere", "Accounts", "LA",5857,32,1020),
("1896", "Melissia Gilma", "Finance", "LA",4455,25,1825),
("1897", "Suzanne Antonina", "HR", "LA",7244,45,700),
("1898", "Norene Tenenbaum", "Marketing", "AK",5124,40,717),
("1899", "Gallman Kensinger", "Accounts", "WA",1688,38,752),
("1900", "Reardon Marvis", "Sales", "CA",1598,45,1422),
("1901", "Figueras Laub", "HR", "WA",1246,32,809),
("1902", "Vivan Stanford", "Marketing", "CA",2289,30,724),
("1903", "Marvis Gallman", "HR", "WA",2566,43,1393),
("1904", "Soules Fender", "Finance", "AK",7540,39,1492),
("1905", "Dionne Marvis", "HR", "WA",7259,32,1074),
("1906", "Larry Megan", "Accounts", "CA",1166,32,906),
("1907", "Mayeda Baros", "Sales", "CA",7247,28,1752),
("1908", "Bergren Figueras", "Finance", "WA",3728,48,1708),
("1909", "Hanh Dedman", "Sales", "AK",6067,36,1300),
("1910", "Mcmillion Kall", "Finance", "WA",5882,46,1308),
("1911", "Rocha Leonel", "Marketing", "AK",7612,47,1269),
("1912", "Frisina Leonel", "Purchasing", "WA",8077,42,579),
("1913", "Ruzicka Phylicia", "Accounts", "NY",1029,41,1132),
("1914", "Ellingsworth Byrge", "Finance", "LA",3413,49,1060),
("1915", "Zollner Figueras", "Sales", "AK",9674,49,1097),
("1916", "Juliana Nakano", "Finance", "CA",8387,42,1012),
("1917", "Clune Frisina", "HR", "CA",4086,36,1912),
("1918", "Nitz Grigg", "Sales", "WA",7356,36,1770),
("1919", "Melvina Leonel", "Purchasing", "CA",8405,25,1165),
("1920", "Mullan Phylicia", "Accounts", "CA",3521,24,1903),
("1921", "Harrison Vankirk", "Finance", "AK",5809,29,1659),
("1922", "Georgeanna Clune", "Marketing", "AK",9043,45,979),
("1923", "Dionne Janey", "Purchasing", "LA",1626,24,1050),
("1924", "Clemencia Yukiko", "Finance", "LA",2511,33,1868),
("1925", "Byrge Herder", "Accounts", "LA",2538,33,1585),
("1926", "Kensinger Louann", "Accounts", "AK",4190,23,1325),
("1927", "Margret Tiffani", "Marketing", "NY",4885,35,1795),
("1928", "Mcmillion Ellingsworth", "HR", "WA",1476,43,1565),
("1929", "Ilana Janey", "Purchasing", "AK",5630,40,1114),
("1930", "Barringer Mcmillion", "Accounts", "CA",1477,48,609),
("1931", "Janine Louann", "Purchasing", "CA",3214,23,673),
("1932", "Nakano Soules", "HR", "WA",2127,42,1319),
("1933", "Luisa Janine", "Accounts", "LA",4256,41,618),
("1934", "Louann Recalde", "Finance", "AK",7189,44,945),
("1935", "Richter Bergren", "Finance", "WA",8728,34,1398),
("1936", "Soules Suzanne", "Sales", "AK",5631,40,854),
("1937", "Stanford Benz", "Sales", "WA",2210,36,1374),
("1938", "Kensinger Nena", "HR", "WA",4754,26,1603),
("1939", "Frisina Mayeda", "Finance", "WA",3406,28,864),
("1940", "Larry Recalde", "Sales", "NY",3065,29,830),
("1941", "Escoto Tiffani", "Finance", "WA",8572,26,607),
("1942", "Figueras Vivan", "Accounts", "LA",8431,27,1853),
("1943", "Debroah Richter", "Purchasing", "WA",4187,38,510),
("1944", "Vankirk Imai", "Sales", "AK",1805,26,992),
("1945", "Ullery Barringer", "Sales", "AK",1418,48,780),
("1946", "Frisina Phylicia", "Accounts", "NY",7579,45,618),
("1947", "Nena Figueras", "Accounts", "WA",3616,36,2000),
("1948", "Lisabeth Ruzicka", "Sales", "WA",7572,35,1888),
("1949", "Deandre Ruzicka", "HR", "CA",8803,42,1373),
("1950", "Herder Reighard", "Purchasing", "WA",6699,24,1099),
("1951", "Richter Larry", "Accounts", "AK",8699,49,1789),
("1952", "Katlyn Megan", "Accounts", "AK",8023,42,1272),
("1953", "Escoto Georgeanna", "Marketing", "CA",7864,34,1278),
("1954", "Kreamer Vivan", "HR", "LA",1205,41,1192),
("1955", "Debroah Lonergan", "Accounts", "CA",8566,40,1838),
("1956", "Vankirk Suzanne", "Purchasing", "AK",8647,20,685),
("1957", "Kensinger Antonina", "Finance", "AK",1093,34,1653),
("1958", "Coogan Larry", "Sales", "NY",3964,48,537),
("1959", "Gallman Richter", "HR", "CA",4061,23,512),
("1960", "Yukiko Ellingsworth", "Accounts", "NY",9065,49,1140),
("1961", "Soules Melissia", "Marketing", "CA",3593,39,1399),
("1962", "Debroah Clemencia", "Sales", "LA",5839,24,1285),
("1963", "Rocha Janine", "Finance", "LA",4827,38,1246),
("1964", "Melvina Antonio", "Purchasing", "WA",1568,41,647),
("1965", "Marvis Hanh", "Purchasing", "CA",1892,48,1202),
("1966", "Luisa Nakano", "Sales", "NY",4124,25,1517),
("1967", "Nena Phylicia", "Purchasing", "AK",2778,29,1718),
("1968", "Jacquelyne Tenenbaum", "Sales", "NY",9159,26,906),
("1969", "Coogan Katlyn", "Purchasing", "WA",1269,43,563),
("1970", "Vivan Clemencia", "Accounts", "WA",3421,48,895),
("1971", "Vivan Mcmillion", "Marketing", "CA",6019,45,1320),
("1972", "Marvis Villela", "Sales", "AK",6355,49,1351),
("1973", "Coogan Margret", "Marketing", "NY",5980,32,1241),
("1974", "Nitz Juliana", "Accounts", "AK",5465,28,1509),
("1975", "Tamra Trena", "Sales", "CA",4158,39,715),
("1976", "Gilma Hanh", "Accounts", "LA",8510,38,1274),
("1977", "Leif Herder", "Accounts", "AK",9266,48,1225),
("1978", "Stanford Clemencia", "Finance", "LA",2350,46,1481),
("1979", "Coogan Villela", "Sales", "LA",4580,45,663),
("1980", "Dionne Kall", "HR", "LA",1013,34,1405),
("1981", "Louann Kreamer", "Purchasing", "LA",3083,50,1501),
("1982", "Clemencia Zollner", "Accounts", "LA",7452,34,1136),
("1983", "Kreamer Toussaint", "Purchasing", "WA",9858,45,715),
("1984", "Kensinger Figueras", "Accounts", "WA",3629,30,585),
("1985", "Jacquelyne Mullan", "Sales", "NY",2030,39,1866),
("1986", "Sifford Shandra", "Finance", "CA",1825,48,1700),
("1987", "Coogan Layla", "Finance", "LA",6142,47,1620),
("1988", "Imai Exie", "Marketing", "NY",8567,29,1493),
("1989", "Toussaint Cobian", "Sales", "CA",7145,22,1520),
("1990", "Cobian Bergren", "HR", "CA",7523,42,1156),
("1991", "Barringer Mullan", "Purchasing", "CA",2569,48,993),
("1992", "Vivan Kensinger", "Marketing", "CA",3652,50,1558),
("1993", "Leonel Tenenbaum", "HR", "CA",7825,33,955),
("1994", "Melvina Clemencia", "Sales", "AK",4470,45,1357),
("1995", "Dionne Sifford", "Sales", "WA",6647,35,984),
("1996", "Megan Coogan", "Sales", "NY",8260,33,1938),
("1997", "Jacquelyne Barringer", "Finance", "CA",9899,22,837),
("1998", "Casimira Ruzicka", "Accounts", "NY",2661,43,1128),
("1999", "Dionne Gilma", "HR", "LA",8389,50,1829),

]

# %%
st_df = spark.createDataFrame(data,schema)
st_df.show(5)
# Out:
# +-----------+-----------------+----------+-----+------+---+-----+
# |employee_id|    employee_name|department|state|salary|age|bonus|
# +-----------+-----------------+----------+-----+------+---+-----+
# |       1000|        Nitz Leif| Marketing|   CA|  6131| 26|  543|
# |       1001|  Melissia Dedman|   Finance|   AK|  4027| 43| 1290|
# |       1002|Rudolph Barringer|        HR|   LA|  3122| 43| 1445|
# |       1003|      Tamra Amber|  Accounts|   AK|  5717| 47| 1291|
# |       1004|      Mullan Nitz|Purchasing|   CA|  5685| 34| 1394|
# +-----------+-----------------+----------+-----+------+---+-----+
# only showing top 5 rows

# %%
st_df.createOrReplaceTempView("st_tbl")

# %%
st_df.count()
st_df.select("employee_id").count()
spark.sql("select count(*) from st_tbl").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    1000|
# +--------+

# %%
st_df.select("department").distinct().count()
# Out:
# Out[78]: 6

# %%
st_df.select("department").distinct().show()
# Out:
# +----------+
# |department|
# +----------+
# |     Sales|
# |        HR|
# |   Finance|
# |Purchasing|
# | Marketing|
# |  Accounts|
# +----------+

# %%
st_df.groupBy("department").agg(count('*').alias("No_of_emp")).show()
# Out:
# +----------+---------+
# |department|No_of_emp|
# +----------+---------+
# |     Sales|      169|
# |        HR|      171|
# |   Finance|      162|
# |Purchasing|      166|
# | Marketing|      170|
# |  Accounts|      162|
# +----------+---------+

# %%
st_df.groupBy("state").count().show()
# Out:
# +-----+-----+
# |state|count|
# +-----+-----+
# |   LA|  205|
# |   CA|  205|
# |   WA|  208|
# |   NY|  173|
# |   AK|  209|
# +-----+-----+

# %%
st_df.groupBy("state","department").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
st_df.groupBy("department") \
    .agg(
        min("salary").alias("minimum_salary"),
        max("salary").alias("maximum_salary")
    ) \
    .orderBy(col("minimum_salary").asc(), col("maximum_salary").asc()) \
    .show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
avg_bonus_value = st_df.filter(st_df.state == "NY").agg(avg('bonus').alias('avg_bonus_of_NY')).collect()[0]['avg_bonus_of_NY']

st_df = st_df.withColumn("avg_bonus_of_NY", lit(avg_bonus_value))

st_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
st_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
st_df.select("employee_name")\
    .filter(st_df.state == 'NY')\
    .filter(st_df.department == 'Finance')\
    .filter(st_df.bonus > st_df.avg_bonus_of_NY).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
def incr_salary(age,current_salary):
    if age > 45:
        current_salary = current_salary + 500
    return current_salary

incr_salary_udf = udf(lambda x,y : incr_salary(x,y),IntegerType())
st_df.withColumn("new_salary",incr_salary_udf(col('age'),col('salary'))).show()
# Out:
# +-----------+-------------------+----------+-----+------+---+-----+----------+
# |employee_id|      employee_name|department|state|salary|age|bonus|new_salary|
# +-----------+-------------------+----------+-----+------+---+-----+----------+
# |       1000|          Nitz Leif| Marketing|   CA|  6131| 26|  543|      6131|
# |       1001|    Melissia Dedman|   Finance|   AK|  4027| 43| 1290|      4027|
# |       1002|  Rudolph Barringer|        HR|   LA|  3122| 43| 1445|      3122|
# |       1003|        Tamra Amber|  Accounts|   AK|  5717| 47| 1291|      6217|
# |       1004|        Mullan Nitz|Purchasing|   CA|  5685| 34| 1394|      5685|
# |       1005|      Zollner Karie|  Accounts|   CA|  2843| 27| 1078|      2843|
# |       1006|Kaczorowski Zollner|     Sales|   CA|  7201| 21| 1834|      7201|
# |       1007|      Nakano Locust| Marketing|   LA|  3444| 23| 1823|      3444|
# |       1008|  Recalde Kensinger|  Accounts|   LA|  3704| 48| 1330|      4204|
# ...

# %%
st_df.show(5)
# Out:
# +-----------+-----------------+----------+-----+------+---+-----+
# |employee_id|    employee_name|department|state|salary|age|bonus|
# +-----------+-----------------+----------+-----+------+---+-----+
# |       1000|        Nitz Leif| Marketing|   CA|  6131| 26|  543|
# |       1001|  Melissia Dedman|   Finance|   AK|  4027| 43| 1290|
# |       1002|Rudolph Barringer|        HR|   LA|  3122| 43| 1445|
# |       1003|      Tamra Amber|  Accounts|   AK|  5717| 47| 1291|
# |       1004|      Mullan Nitz|Purchasing|   CA|  5685| 34| 1394|
# +-----------+-----------------+----------+-----+------+---+-----+
# only showing top 5 rows

# %%
st_df.filter(st_df.age > 45).write.csv("dbfs_")
